# %%
import os
import json

# Set paths
datasets_dir = '../../../datasets'
vqax_dir = os.path.join(datasets_dir, 'VQA-X')
train_dir = os.path.join(vqax_dir, 'vqaX_train.json')
test_dir = os.path.join(vqax_dir, 'vqaX_test.json')
val_dir = os.path.join(vqax_dir, 'vqaX_val.json')
with open(train_dir) as f:
    train_data = json.load(f)
with open(test_dir) as f:
    test_data = json.load(f)
with open(val_dir) as f:
    val_data = json.load(f)

# %%
print(json.dumps(test_data['262284001'],indent=2))
# Out:
# {
#   "question": "What is this?",
#   "answers": [
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 1
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 2
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 3
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 4
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "maybe",
#       "answer_id": 5
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 6
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 7
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 8
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 9
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 10
#     }
#   ],
#   "image_id": "262284",
#   "image_name": "COCO_val2014_000000262284.jpg",
#   "explanation": [
#     "it has a shower head hanging inside of it",
#     "there is a shower head",
#     "there is a faucet and a bathtub"
#   ]
# }

# %% [markdown]
# ## Combine translations into one object

# %% [markdown]
# ## Verifying the translations

# %%
import json
import os

# Đường dẫn đến thư mục chứa các file dữ liệu
datasets_dir = '../../../datasets/VQA-X'

# Danh sách các tập dữ liệu
datasets = ['train', 'val', 'test']

# Danh sách các nguồn dịch
translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

def check_data_integrity(datasets_dir, datasets, translation_sources):
    for dataset in datasets:
        print(f"Checking {dataset} dataset...")
        
        # Load merged data
        merged_file = f'{datasets_dir}/vqaX_{dataset}_translated.json'
        merged_data = load_json(merged_file)
        
        error_items = {}
        
        for key, item in merged_data.items():
            item_errors = []
            
            # Check original fields
            if not item['question'] or not item['answers'] or not item['explanation']:
                item_errors.append("Missing original fields")
            
            # Check translated fields
            for source in translation_sources:
                question_key = f'question_vi_{source}'
                answer_key = f'answer_vi_{source}'
                explanation_key = f'explanation_vi_{source}'
                
                if question_key not in item or not item[question_key]:
                    item_errors.append(f"Missing or empty {question_key}")
                
                if answer_key not in item or not item[answer_key]:
                    item_errors.append(f"Missing or empty {answer_key}")
                
                if explanation_key not in item:
                    item_errors.append(f"Missing {explanation_key}")
                elif not item[explanation_key]:
                    item_errors.append(f"Empty {explanation_key}")
                elif len(item[explanation_key]) != len(item['explanation']):
                    item_errors.append(f"Mismatch in number of explanations for {explanation_key}")
                elif any(not exp for exp in item[explanation_key]):
                    item_errors.append(f"Empty explanation in {explanation_key}")
            
            if item_errors:
                error_items[key] = item_errors
        
        # Save error items
        error_file = f'{dataset}_errors.json'
        with open(error_file, 'w', encoding='utf-8') as f:
            json.dump(error_items, f, ensure_ascii=False, indent=2)
        
        print(f"Total items: {len(merged_data)}")
        print(f"Items with errors: {len(error_items)}")
        print("\n")

# Run the integrity check
check_data_integrity(datasets_dir, datasets, translation_sources)
# Out:
# Checking train dataset...
# Total items: 29459
# Items with errors: 0
#
#
# Checking val dataset...
# Total items: 1459
# Items with errors: 0
#
#
# Checking test dataset...
# Total items: 1968
# Items with errors: 0

# %%
import json
import os

# Đường dẫn đến thư mục chứa các file dữ liệu
datasets_dir = '../../../datasets/VQA-X'

# Danh sách các tập dữ liệu
datasets = ['train', 'val', 'test']

# Danh sách các nguồn dịch
translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

def merge_translations(datasets_dir, datasets, translation_sources):
    for dataset in datasets:
        print(f"Processing {dataset} dataset...")
        
        # Load original data
        original_file = f'{datasets_dir}/vqaX_{dataset}.json'
        original_data = load_json(original_file)
        
        # Load translations
        translations = {}
        for source in translation_sources:
            translation_file = f'{datasets_dir}/vqaX_{dataset}_{source}.json'
            if os.path.exists(translation_file):
                translations[source] = load_json(translation_file)
            else:
                print(f"Warning: {translation_file} not found. Skipping this translation source.")
        
        # Merge translations
        merged_data = {}
        for key, item in original_data.items():
            merged_item = item.copy()
            for source in translation_sources:
                if source in translations and key in translations[source]:
                    translated_item = translations[source][key]
                    merged_item[f'question_vi_{source}'] = translated_item.get(f'question_vi_{source}')
                    merged_item[f'answer_vi_{source}'] = translated_item.get(f'answer_vi_{source}')
                    merged_item[f'explanation_vi_{source}'] = translated_item.get(f'explanation_vi_{source}')
            merged_data[key] = merged_item
        
        # Save merged data
        output_file = f'{datasets_dir}/vqaX_{dataset}_translated.json'
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(merged_data, f, ensure_ascii=False, indent=2)
        print(f"Merged data saved to {output_file}")
        
        # Print some statistics
        print(f"Total items in original data: {len(original_data)}")
        print(f"Total items in merged data: {len(merged_data)}")
        for source in translation_sources:
            if source in translations:
                print(f"Items with {source} translation: {sum(1 for item in merged_data.values() if f'question_vi_{source}' in item)}")
        print("\n")

# Run the merging process
merge_translations(datasets_dir, datasets, translation_sources)
# Out:
# Processing train dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_train_translated.json
# Total items in original data: 29459
# Total items in merged data: 29459
# Items with vinai translation: 29459
# Items with gemini translation: 29459
# Items with ggtrans translation: 29459
# Items with gpt translation: 29459
#
#
# Processing val dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_val_translated.json
# Total items in original data: 1459
# Total items in merged data: 1459
# Items with vinai translation: 1459
# Items with gemini translation: 1459
# Items with ggtrans translation: 1459
# Items with gpt translation: 1459
#
#
# Processing test dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_test_translated.json
# Total items in original data: 1968
# Total items in merged data: 1968
# Items with vinai translation: 1968
# Items with gemini translation: 1968
# Items with ggtrans translation: 1968
# Items with gpt translation: 1968

# %% [markdown]
# ## Visualize translations

# %%
import os
import json
import pandas as pd
import numpy as np
import random
random.seed(0)
# Đường dẫn tới thư mục datasets và evaluation
datasets_dir = '../../../datasets/VQA-X'
with open(os.path.join(datasets_dir, 'vqaX_val_translated.json')) as f:
    val_data = json.load(f)

vote_dir = os.path.join(datasets_dir, 'data_csv_final_voting')
argmax_data = pd.read_csv(os.path.join(vote_dir, 'argmax.csv'))
sampling_data = pd.read_csv(os.path.join(vote_dir, 'sampling.csv'))
# id_image,question,answer,explanation

argmax_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_image     1459 non-null   int64
#  1   question     1459 non-null   object
#  2   answer       1459 non-null   object
#  3   explanation  1459 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 45.7+ KB

# %%
# random id_image in train_data
indices = random.sample(list(val_data.keys()), 100)
translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']
# print original, argmax, sampling and translation
for idx in indices:
    print(f"ID: {idx}")
    print(f"explanation: {val_data[idx]['explanation']}")
    print(f"Argmax: {argmax_data[argmax_data['id_image'] == int(idx)]['explanation'].values[0]}")
    print(f"Sampling: {sampling_data[sampling_data['id_image'] == int(idx)]['explanation'].values[0]}")
    print(f"Translation: ")
    for source in translation_sources:
        print(f"  {source}: {val_data[idx][f'explanation_vi_{source}']}")
    print("=====================================")
# Out:
# ID: 262651002
# explanation: ['this boat is a large barge', 'it is designed to move cargo', 'it is a large boat for cargo']
# Argmax: chiếc thuyền này là một chiếc sà lan lớn; nó được thiết kế để di chuyển hàng hóa; nó là một chiếc thuyền lớn để chở hàng
# Sampling: Thuyền này là một sà lan lớn.; nó được thiết kế để di chuyển hàng hóa; nó là một chiếc thuyền lớn để chở hàng
# Translation:
#   vinai: ['Thuyền này là một sà lan lớn.', 'nó được thiết kế để di chuyển hàng hóa', 'nó là một chiếc thuyền lớn để chở hàng']
#   gemini: ['chiếc thuyền này là một chiếc sà lan lớn', 'nó được thiết kế để di chuyển hàng hóa', 'đó là một chiếc thuyền lớn để chở hàng hóa']
#   ggtrans: ['chiếc thuyền này là một chiếc sà lan lớn', 'nó được thiết kế để di chuyển hàng hóa', 'nó là một chiếc thuyền lớn để chở hàng']
#   gpt: ['chiếc thuyền này là một chiếc xà lan lớn', 'nó được thiết kế để vận chuyển hàng hóa', 'nó là một chiếc thuyền lớn dành cho hàng hóa']
# =====================================
# ID: 558673000
# explanation: ['there is a lot of furniture in there', 'the room is full of furniture and a television set', 'there is open mail on the table']
# Argmax: Có rất nhiều đồ đạc trong đó.; căn phòng đầy đủ đồ nội thất và một TV; có thư mở trên bàn
# Sampling: Có rất nhiều đồ đạc trong đó.; căn phòng đầy đủ đồ nội thất và một TV; có một lá thư đang mở trên bàn
# Translation:
#   vinai: ['Có rất nhiều đồ đạc trong đó.', 'căn phòng đầy đủ đồ nội thất và một TV', 'có thư mở trên bàn']
#   gemini: ['có rất nhiều đồ đạc ở trong đó', 'căn phòng đầy đồ đạc và một chiếc tivi', 'có thư chưa mở trên bàn']
#   ggtrans: ['có rất nhiều đồ đạc trong đó', 'căn phòng có đầy đủ đồ đạc và một chiếc tivi', 'có một lá thư đang mở trên bàn']
#   gpt: ['có nhiều đồ đạc bên trong', 'căn phòng đầy đồ đạc và một chiếc ti vi', 'có thư mở trên bàn']
# =====================================
# ID: 2759000
# explanation: ['it is covered in brown', 'it is rusted and old-looking', 'it has flecks of rust on it']
# Argmax: nó được bao phủ bởi màu nâu; nó bị rỉ sét và trông cũ kỹ; Nó có những vết rỉ sét trên đó.
# Sampling: nó được bao phủ bởi màu nâu; nó bị rỉ sét và trông cũ kỹ; nó có những vết rỉ sét trên đó
# Translation:
#   vinai: ['nó được bao phủ trong màu nâu', 'nó bị rỉ sét và cũ', 'Nó có những vết rỉ sét trên đó.']
#   gemini: ['nó được bao phủ bởi màu nâu', 'nó bị rỉ sét và trông cũ kỹ', 'nó có những mảnh rỉ sét trên đó']
#   ggtrans: ['nó được bao phủ bởi màu nâu', 'nó bị rỉ sét và trông cũ kỹ', 'nó có những vết rỉ sét trên đó']
#   gpt: ['nó bị phủ bởi màu nâu', 'nó đã rỉ sét và có vẻ cũ kỹ', 'nó có những đốm rỉ sét trên đó']
# =====================================
# ID: 262531001
# explanation: ["he's riding on a skateboard", 'he is bent low atop a board with wheels', 'he is riding on a skateboard']
# Argmax: anh ấy đang đi trên ván trượt; Anh ta cúi thấp trên một tấm ván có bánh xe; anh ấy đang đi trên ván trượt
# Sampling: anh ấy đang cưỡi ván trượt; Anh ta cúi thấp trên một tấm ván có bánh xe; anh ấy đang đi trên ván trượt
# Translation:
#   vinai: ['Hắn đang cưỡi trên ván trượt.', 'Anh ta cúi thấp trên một tấm ván có bánh xe', 'Anh ta đang cưỡi trên ván trượt.']
#   gemini: ['anh ấy đang cưỡi ván trượt', 'anh ấy cúi người trên một tấm ván có bánh xe', 'anh ấy đang cưỡi ván trượt']
#   ggtrans: ['anh ấy đang đi trên ván trượt', 'anh ta cúi thấp trên một tấm ván có bánh xe', 'anh ấy đang đi trên ván trượt']
#   gpt: ['anh ấy đang đạp trên một cái ván trượt', 'anh ấy cúi thấp trên một cái ván có bánh xe', 'anh ấy đang đạp trên một cái ván trượt']
# =====================================
# ID: 124072002
# explanation: ['all the decorations are in wedding style fashion', 'there is a table with a wedding cake on top of it', 'a wedding cake is placed on a decorated table']
# Argmax: tất cả các đồ trang trí đều theo phong cách đám cưới; Có một cái bàn với một cái bánh cưới trên đó.; một chiếc bánh cưới được đặt trên một chiếc bàn được trang trí
# Sampling: tất cả các đồ trang trí đều theo phong cách đám cưới; Có một cái bàn với một cái bánh cưới trên đó.; một chiếc bánh cưới được đặt trên một chiếc bàn được trang trí
# Translation:
#   vinai: ['tất cả các đồ trang trí là trong thời trang phong cách đám cưới', 'Có một cái bàn với một cái bánh cưới trên đó.', 'một chiếc bánh cưới được đặt trên một chiếc bàn trang trí']
#   gemini: ['tất cả các đồ trang trí đều theo phong cách đám cưới', 'có một bàn với bánh cưới ở trên', 'một chiếc bánh cưới được đặt trên một chiếc bàn được trang trí']
#   ggtrans: ['tất cả các đồ trang trí đều theo phong cách đám cưới', 'có một cái bàn với một chiếc bánh cưới ở trên', 'một chiếc bánh cưới được đặt trên một chiếc bàn được trang trí']
#   gpt: ['tất cả các trang trí đều theo phong cách đám cưới', 'có một bàn với một chiếc bánh cưới trên đó', 'một chiếc bánh cưới được đặt trên một bàn được trang trí']
# =====================================
# ID: 94746001
# explanation: ['plenty of suits are present in the background', 'there are rows and rows of suits on the wall and on the racks', 'there are a lot of blazers hanging on racks']
# Argmax: rất nhiều bộ quần áo có mặt trong nền; có hàng và hàng vest trên tường và trên giá; có rất nhiều áo blazer treo trên giá
# Sampling: rất nhiều bộ quần áo có mặt trong nền; có hàng và hàng vest trên tường và trên giá; có rất nhiều áo blazer treo trên giá
# Translation:
#   vinai: ['rất nhiều bộ quần áo có mặt trong nền', 'Có hàng dãy quần áo trên tường và trên giá đỡ.', 'có rất nhiều áo khoác treo trên kệ']
#   gemini: ['rất nhiều vest có mặt trong nền', 'có hàng và hàng vest trên tường và trên giá', 'có rất nhiều áo khoác blazer treo trên giá']
#   ggtrans: ['rất nhiều bộ quần áo hiện diện trong nền', 'có hàng dãy quần áo trên tường và trên giá', 'có rất nhiều áo blazer treo trên giá']
#   gpt: ['nhiều bộ đồ có sẵn trong nền', 'có hàng hàng bộ đồ trên tường và trên kệ', 'có rất nhiều áo khoác treo trên kệ']
# =====================================
# ID: 389812003
# explanation: ['he has lots of wrinkles and leathery skin', 'he is much older than that', 'he is starting to go bald']
# Argmax: anh ấy có rất nhiều nếp nhăn và làn da sạm màu; anh ấy lớn tuổi hơn thế nhiều; Anh ta bắt đầu hói.
# Sampling: Anh ta có nhiều nếp nhăn và da nhăn nheo.; anh ấy lớn tuổi hơn thế nhiều; anh ấy bắt đầu bị hói
# Translation:
#   vinai: ['Anh ta có nhiều nếp nhăn và da nhăn nheo.', 'Ông ấy già hơn thế nhiều.', 'Anh ta bắt đầu hói.']
#   gemini: ['anh ta có rất nhiều nếp nhăn và da rám nắng', 'anh ta già hơn nhiều so với tuổi đó', 'anh ta bắt đầu bị hói']
#   ggtrans: ['anh ấy có rất nhiều nếp nhăn và làn da sạm màu', 'anh ấy lớn tuổi hơn thế nhiều', 'anh ấy đang bắt đầu hói']
#   gpt: ['anh ấy có nhiều nếp nhăn và làn da xỉn màu', 'anh ấy già hơn nhiều so với điều đó', 'anh ấy bắt đầu bị hói']
# =====================================
# ID: 541123002
# explanation: ['they are holding rackets on a tennis court', 'players holding racquets are on opposite sides of the net on a doubles court', 'they are all holding rackets']
# Argmax: họ đang cầm vợt trên sân tennis; Người chơi cầm vợt ở hai phía đối diện của lưới trên sân đôi; Tất cả họ đều đang cầm vợt.
# Sampling: họ đang cầm vợt trên sân tennis; các cầu thủ cầm vợt ở hai bên lưới trên một sân đấu đôi; họ đều đang cầm vợt
# Translation:
#   vinai: ['Họ đang cầm vợt trên sân tennis.', 'Người chơi cầm vợt ở hai phía đối diện của lưới trên sân đôi', 'Tất cả họ đều đang cầm vợt.']
#   gemini: ['họ đang cầm vợt trên sân quần vợt', 'các cầu thủ cầm vợt ở hai bên lưới trên một sân đấu đôi', 'tất cả họ đều cầm vợt']
#   ggtrans: ['họ đang cầm vợt trên sân tennis', 'người chơi cầm vợt đứng ở hai phía đối diện của lưới trên sân đánh đôi', 'tất cả họ đều đang cầm vợt']
#   gpt: ['họ đang cầm vợt trên sân quần vợt', 'các vận động viên cầm vợt đứng ở hai bên lưới trên sân đánh đôi', 'họ đều đang cầm vợt']
# =====================================
# ID: 423618001
# explanation: ['plastic can withstand the force of sharp knives', 'it is a hard white material', 'it has a textured acrylic appearance']
# Argmax: nhựa có thể chịu được lực của dao sắc; nó là một vật liệu cứng màu trắng; nó có vẻ ngoài như acrylic có kết cấu
# Sampling: nhựa có thể chịu được lực của dao sắc; nó là một vật liệu trắng cứng; nó có bề ngoài kết cấu acrylic
# Translation:
#   vinai: ['nhựa có thể chịu được lực của dao sắc', 'nó là một vật liệu trắng cứng', 'nó có kết cấu acrylic']
#   gemini: ['nhựa có thể chịu được lực của dao sắc', 'nó là một vật liệu trắng cứng', 'nó có bề mặt acrylic có vân']
#   ggtrans: ['nhựa có thể chịu được lực của dao sắc', 'nó là một vật liệu cứng màu trắng', 'nó có bề ngoài kết cấu acrylic']
#   gpt: ['nhựa có thể chịu được lực của những con dao sắc bén', 'nó là một chất liệu trắng cứng', 'nó có vẻ ngoài như acrylic có kết cấu']
# =====================================
# ID: 282328002
# explanation: ['it has lots of broccoli in it', 'there is brocoli', 'the dish is mostly broccoli']
# Argmax: nó có rất nhiều bông cải xanh trong đó; có brocoli; món ăn chủ yếu là bông cải xanh
# Sampling: nó có rất nhiều bông cải xanh trong đó; có bông cải xanh.; món ăn chủ yếu là bông cải xanh
# Translation:
#   vinai: ['nó có rất nhiều bông cải xanh trong đó', 'có brocoli', 'các món ăn chủ yếu là bông cải xanh']
#   gemini: ['nó có rất nhiều bông cải xanh', 'có bông cải xanh', 'món ăn chủ yếu là bông cải xanh']
#   ggtrans: ['nó có rất nhiều bông cải xanh trong đó', 'có bông cải xanh', 'món ăn chủ yếu là bông cải xanh']
#   gpt: ['nó có nhiều bông cải xanh ở trong.', 'có bông cải xanh.', 'món ăn chủ yếu là bông cải xanh']
# =====================================
# ID: 109797000
# explanation: ['the room has couches and a fireplace with a photo over the mantle', 'a couch sits on one side of a coffee table in front of a fireplace', 'there are couches and a fireplace']
# Argmax: căn phòng có ghế sofa và lò sưởi với một bức ảnh trên lò sưởi; một chiếc ghế sofa nằm bên một bên của bàn cà phê trước lò sưởi.; có ghế sofa và một lò sưởi.
# Sampling: căn phòng có những chiếc ghế dài và một lò sưởi với một bức ảnh trên lớp áo choàng; một chiếc ghế dài nằm ở một bên bàn cà phê trước lò sưởi; có ghế dài và lò sưởi
# Translation:
#   vinai: ['căn phòng có ghế dài và lò sưởi với một bức ảnh trên lớp phủ', 'một chiếc ghế dài ngồi ở một bên của bàn cà phê trước lò sưởi', 'có ghế dài và lò sưởi']
#   gemini: ['căn phòng có ghế sofa và lò sưởi với một bức ảnh trên lò sưởi', 'một chiếc ghế sofa nằm ở một bên của bàn cà phê trước lò sưởi', 'có ghế sofa và lò sưởi']
#   ggtrans: ['căn phòng có những chiếc ghế dài và một lò sưởi với một bức ảnh trên lớp áo choàng', 'một chiếc ghế dài nằm ở một bên bàn cà phê trước lò sưởi', 'có những chiếc ghế dài và một lò sưởi']
#   gpt: ['căn phòng có ghế sofa và một lò sưởi với một bức ảnh trên bệ.', 'một chiếc ghế sofa nằm bên một bên của bàn cà phê trước lò sưởi.', 'có ghế sofa và một lò sưởi.']
# =====================================
# ID: 369323005
# explanation: ['she is holding a tennis raquet', 'she is swinging a tennis racket', 'she is getting ready to swing a tennis racket']
# Argmax: cô ấy đang cầm một cây vợt tennis; cô ấy đang vung vợt tennis; cô ấy đang chuẩn bị vung vợt tennis
# Sampling: cô ấy đang cầm một chiếc vợt tennis; cô ấy đang vung một chiếc vợt tennis; cô ấy đang chuẩn bị vung vợt quần vợt
# Translation:
#   vinai: ['cô ấy đang cầm một cây vợt tennis', 'cô ấy đang đu một vợt tennis', 'cô ấy đang chuẩn bị để đu một cây vợt tennis']
#   gemini: ['cô ấy đang cầm vợt quần vợt', 'cô ấy đang vung vợt quần vợt', 'cô ấy đang chuẩn bị vung vợt quần vợt']
#   ggtrans: ['cô ấy đang cầm một cây vợt tennis', 'cô ấy đang vung vợt tennis', 'cô ấy đang chuẩn bị vung vợt tennis']
#   gpt: ['cô ấy đang cầm một chiếc vợt tennis', 'cô ấy đang vung một chiếc vợt tennis', 'cô ấy đang chuẩn bị để vung một chiếc vợt tennis']
# =====================================
# ID: 162827001
# explanation: ['the powdered donut has finger prints in it from being picked up', 'there seems to be sugar crumbs around the plate', 'the powder shakes off and sticks to clothes']
# Argmax: Bánh rán bột có dấu vân tay khi được nhặt lên.; Có vẻ như có vụn đường xung quanh đĩa.; bột bong ra và dính vào quần áo
# Sampling: Bánh rán bột có dấu vân tay khi được nhặt lên.; có vẻ như có vụn đường xung quanh đĩa; bột rơi ra và dính vào quần áo
# Translation:
#   vinai: ['Bánh rán bột có dấu vân tay khi được nhặt lên.', 'Có vẻ như có vụn đường xung quanh đĩa.', 'bột lắc ra và dính vào quần áo']
#   gemini: ['chiếc bánh rán có bột có dấu vân tay khi được nhấc lên', 'có vẻ như có vụn đường xung quanh đĩa', 'bột rơi ra và dính vào quần áo']
#   ggtrans: ['chiếc bánh rán bột có dấu vân tay khi được nhặt lên', 'dường như có vụn đường xung quanh đĩa', 'bột bong ra và dính vào quần áo']
#   gpt: ['bánh donut bột có dấu tay trên đó từ việc được cầm lên', 'có vẻ có những vụn đường quanh đĩa', 'bột rơi ra và dính vào quần áo']
# =====================================
# ID: 444028007
# explanation: ['he has a tennis racket', 'he has a tennis racket by his side', 'he has a racket next to his feet, and the brand penn is on the side of his bench']
# Argmax: anh ấy có một cây vợt tennis; anh ấy có một cây vợt tennis bên cạnh; anh ấy có một cây vợt bên cạnh chân và đồng xu thương hiệu ở bên cạnh băng ghế của anh ấy
# Sampling: anh ấy có một cây vợt tennis; Anh ấy có vợt tennis bên cạnh.; anh ấy có một cây vợt bên cạnh chân và đồng xu thương hiệu ở bên cạnh băng ghế của anh ấy
# Translation:
#   vinai: ['Anh ta có vợt tennis.', 'Anh ấy có vợt tennis bên cạnh.', 'ông có một vợt bên cạnh bàn chân của mình, và thương hiệu penn là ở bên cạnh của băng ghế dự bị của mình']
#   gemini: ['anh ấy có một cây vợt tennis', 'anh ấy có một cây vợt tennis bên cạnh', 'anh ấy có một cây vợt bên cạnh chân, và thương hiệu penn ở bên cạnh băng ghế của anh ấy']
#   ggtrans: ['anh ấy có một cây vợt tennis', 'anh ấy có một cây vợt tennis bên cạnh', 'anh ấy có một cây vợt bên cạnh chân và đồng xu thương hiệu ở bên cạnh băng ghế của anh ấy']
#   gpt: ['anh ấy có một cây vợt tennis', 'anh ấy có một cây vợt tennis bên cạnh', 'anh ấy có một cây vợt bên cạnh chân, và thương hiệu Penn nằm ở bên cạnh ghế của anh ấy']
# =====================================
# ID: 308223001
# explanation: ['the goalie is preparing to defend the goal', 'a boy is staning in a goal and wearing cleats near a round ball', 'there is a soccer ball on the ground']
# Argmax: thủ môn đang chuẩn bị bảo vệ khung thành; một cậu bé đang đứng trong khung thành và mang giày đinh gần một quả bóng tròn; có một quả bóng đá trên mặt đất
# Sampling: thủ môn đang chuẩn bị bảo vệ khung thành; một cậu bé đang đứng trong khung thành và mang giày đinh gần một quả bóng tròn; có một quả bóng đá trên mặt đất
# Translation:
#   vinai: ['thủ môn đang chuẩn bị để bảo vệ mục tiêu', 'một cậu bé là staning trong một mục tiêu và mặc cleats gần một vòng bóng', 'Có một quả bóng đá trên mặt đất.']
#   gemini: ['thủ môn đang chuẩn bị phòng thủ khung thành', 'một cậu bé đang đứng trong khung thành và mang giày đinh gần một quả bóng tròn', 'có một quả bóng đá trên mặt đất']
#   ggtrans: ['thủ môn đang chuẩn bị bảo vệ khung thành', 'một cậu bé đang đứng trong khung thành và mang giày gần một quả bóng tròn', 'có một quả bóng đá trên mặt đất']
#   gpt: ['thủ môn đang chuẩn bị để bảo vệ khung thành', 'một cậu bé đang đứng trong khung thành và mang giày đinh gần một quả bóng tròn', 'có một quả bóng đá trên mặt đất']
# =====================================
# ID: 256983002
# explanation: ['there are cubs players and cubs fans', 'the woman is wearing a cubs hat', 'there are baseball players in uniform in the background']
# Argmax: có các cầu thủ Cubs và người hâm mộ Cubs; người phụ nữ đang đội mũ cubs; có các cầu thủ bóng chày đang mặc đồng phục ở phía sau
# Sampling: có các cầu thủ Cubs và người hâm mộ Cubs; người phụ nữ đang đội một con cubs mũ; có những cầu thủ bóng chày mặc đồng phục ở phía sau
# Translation:
#   vinai: ['có cầu thủ cubs và người hâm mộ cubs', 'người phụ nữ đang đội một con cubs mũ', 'có những cầu thủ bóng chày mặc đồng phục ở phía sau']
#   gemini: ['có những cầu thủ cubs và người hâm mộ cubs', 'người phụ nữ đang đội mũ cubs', 'có những cầu thủ bóng chày mặc đồng phục ở hậu cảnh']
#   ggtrans: ['có những người chơi đàn con và những người hâm mộ đàn con', 'người phụ nữ đang đội một chiếc mũ dành cho trẻ em', 'có những cầu thủ bóng chày mặc đồng phục ở phía sau']
#   gpt: ['có các cầu thủ Cubs và người hâm mộ Cubs', 'người phụ nữ đang đội mũ Cubs', 'có các cầu thủ bóng chày đang mặc đồng phục ở phía sau']
# =====================================
# ID: 160351001
# explanation: ['the board he is standing on has wheels attached to it', 'the young man is standing on a skateboard', 'he stands on a board on wheels on pavement']
# Argmax: chiếc ván mà anh ấy đang đứng có bánh xe gắn vào.; chàng trai trẻ đang đứng trên ván trượt; anh ấy đứng trên một tấm ván có bánh xe trên vỉa hè
# Sampling: Tấm ván nó đang đứng có gắn bánh xe.; Chàng trai trẻ đang đứng trên ván trượt.; anh ấy đứng trên một tấm ván có bánh xe trên vỉa hè
# Translation:
#   vinai: ['Tấm ván nó đang đứng có gắn bánh xe.', 'Chàng trai trẻ đang đứng trên ván trượt.', 'ông đứng trên một bảng trên bánh xe trên vỉa hè']
#   gemini: ['cái ván anh ta đứng có gắn bánh xe', 'người thanh niên đang đứng trên ván trượt', 'anh ấy đứng trên một tấm ván có bánh xe trên vỉa hè']
#   ggtrans: ['tấm ván anh ấy đang đứng có gắn bánh xe', 'chàng trai trẻ đang đứng trên ván trượt', 'anh ấy đứng trên một tấm ván có bánh xe trên vỉa hè']
#   gpt: ['chiếc ván mà anh ấy đang đứng có bánh xe gắn vào.', 'người đàn ông trẻ đang đứng trên một chiếc ván trượt.', 'anh ấy đứng trên một chiếc ván có bánh xe trên mặt đường.']
# =====================================
# ID: 410496000
# explanation: ['with his arm behind him preparing for the volley the tennis player is alert', 'a man is on a tennis court', 'the player is standing on a clay tennis court']
# Argmax: với cánh tay sau lưng chuẩn bị cho cú vô lê, người chơi quần vợt rất cảnh giác; một người đàn ông đang ở trên sân tennis; người chơi đang đứng trên sân tennis đất nện
# Sampling: với cánh tay sau lưng chuẩn bị cho cú vô lê, người chơi quần vợt rất cảnh giác; một người đàn ông đang ở trên một sân tennis; người chơi đang đứng trên sân quần vợt đất nện
# Translation:
#   vinai: ['với cánh tay của mình phía sau anh ta chuẩn bị cho bóng chuyền các cầu thủ quần vợt là cảnh báo', 'một người đàn ông đang ở trên một sân tennis', 'người chơi đang đứng trên một sân tennis đất sét']
#   gemini: ['với cánh tay ở phía sau chuẩn bị cho cú đánh volley, tay vợt quần vợt rất tỉnh táo', 'một người đàn ông đang ở sân quần vợt', 'tay vợt đang đứng trên sân đất nện']
#   ggtrans: ['với cánh tay sau lưng chuẩn bị cho cú vô lê, người chơi quần vợt rất cảnh giác', 'một người đàn ông đang ở trên sân tennis', 'người chơi đang đứng trên sân tennis đất nện']
#   gpt: ['với cánh tay ở phía sau chuẩn bị cho cú đánh, tay vợt rất tỉnh táo', 'một người đàn ông đang ở trên sân quần vợt', 'người chơi đang đứng trên sân quần vợt đất nện']
# =====================================
# ID: 84984006
# explanation: ['there are two people in the water on surfboards', 'they are riding the waves in the ocean', 'they are in the ocean in wet suits']
# Argmax: có hai người ở dưới nước trên ván lướt sóng; họ đang cưỡi sóng trên đại dương; Họ đang ở trong đại dương trong bộ đồ ướt.
# Sampling: có hai người trong nước trên ván lướt sóng; họ đang cưỡi sóng trong đại dương; họ đang ở trong đại dương trong bộ đồ lướt sóng
# Translation:
#   vinai: ['Có hai người trên ván lướt sóng.', 'họ đang cưỡi những con sóng trong đại dương', 'Họ đang ở trong đại dương trong bộ đồ ướt.']
#   gemini: ['có hai người trong nước trên ván lướt sóng', 'họ đang cưỡi sóng trong đại dương', 'họ đang ở trong đại dương trong bộ đồ lướt sóng']
#   ggtrans: ['có hai người ở dưới nước trên ván lướt sóng', 'họ đang cưỡi sóng trên đại dương', 'họ đang ở dưới biển trong bộ đồ ướt']
#   gpt: ['có hai người trong nước trên ván lướt', 'họ đang cưỡi sóng trong đại dương', 'họ đang ở trong đại dương trong bộ đồ lặn']
# =====================================
# ID: 199003002
# explanation: ['the one has its face down near the grass', 'they are eating grass in a field', 'the zebras are standing in a field eating grass']
# Argmax: con có khuôn mặt của nó xuống gần cỏ; họ đang ăn cỏ trên cánh đồng; những con ngựa vằn đang đứng trong một cánh đồng ăn cỏ
# Sampling: một con úp mặt gần bãi cỏ; chúng đang ăn cỏ trong một cánh đồng; những con ngựa vằn đang đứng trong một cánh đồng ăn cỏ
# Translation:
#   vinai: ['con có khuôn mặt của nó xuống gần cỏ', 'Họ đang ăn cỏ trên cánh đồng.', 'Ngựa vằn đang đứng trên cánh đồng ăn cỏ.']
#   gemini: ['con ngựa vằn đang cúi đầu gần cỏ', 'chúng đang ăn cỏ trong một cánh đồng', 'những con ngựa vằn đang đứng trong một cánh đồng ăn cỏ']
#   ggtrans: ['một con úp mặt gần bãi cỏ', 'họ đang ăn cỏ trên cánh đồng', 'ngựa vằn đang đứng trên cánh đồng ăn cỏ']
#   gpt: ['con ở phía dưới có mặt gần cỏ', 'chúng đang ăn cỏ trong một cánh đồng', 'những con ngựa vằn đang đứng trong một cánh đồng ăn cỏ']
# =====================================
# ID: 376236000
# explanation: ['he have a short sleeve shirt over his long sleeve shirt', 'he has both a short sleeve and long sleeve shirt on', 'he is wearing two shirts layered together']
# Argmax: Anh ta mặc áo sơ mi ngắn tay bên ngoài áo sơ mi dài tay.; cậu ấy mặc cả áo tay ngắn và áo tay dài.; anh ấy đang mặc hai chiếc áo sơ mi xếp chồng lên nhau
# Sampling: cậu ấy mặc áo sơ mi ngắn tay bên ngoài áo sơ mi dài tay; cậu ấy mặc cả áo tay ngắn và áo tay dài.; anh ấy đang mặc hai chiếc áo sơ mi xếp chồng lên nhau
# Translation:
#   vinai: ['Anh ta mặc áo sơ mi ngắn tay bên ngoài áo sơ mi dài tay.', 'anh ta có cả áo ngắn tay và áo dài tay', 'Anh ta mặc hai chiếc áo xếp lớp với nhau.']
#   gemini: ['cậu ấy mặc áo sơ mi ngắn tay bên ngoài áo sơ mi dài tay', 'cậu ấy mặc cả áo sơ mi ngắn tay và dài tay', 'cậu ấy mặc hai chiếc áo chồng lên nhau']
#   ggtrans: ['anh ấy mặc một chiếc áo sơ mi ngắn tay bên ngoài chiếc áo sơ mi dài tay', 'anh ấy mặc cả áo sơ mi ngắn tay và dài tay', 'anh ấy đang mặc hai chiếc áo sơ mi xếp chồng lên nhau']
#   gpt: ['cậu ấy có một chiếc áo tay ngắn ở bên ngoài chiếc áo tay dài.', 'cậu ấy mặc cả áo tay ngắn và áo tay dài.', 'cậu ấy đang mặc hai chiếc áo chồng lên nhau.']
# =====================================
# ID: 145295001
# explanation: ['it is national go skate boarding day in the city', 'they are standing on boards and riding down the street', 'they are racing their skateboards in a big city']
# Argmax: đây là ngày trượt ván quốc gia trong thành phố; họ đang đứng trên ván và đi xuống phố; họ đang đua ván trượt ở một thành phố lớn
# Sampling: hôm nay là ngày đi ván trượt quốc gia ở thành phố.; họ đang đứng trên ván và lướt xuống đường; Họ đang đua ván trượt trong một thành phố lớn.
# Translation:
#   vinai: ['đây là ngày trượt ván quốc gia trong thành phố', 'Họ đang đứng trên ván và cưỡi ngựa xuống đường.', 'Họ đang đua ván trượt trong một thành phố lớn.']
#   gemini: ['đó là ngày quốc gia trượt ván ở thành phố', 'họ đang đứng trên ván và lướt xuống đường', 'họ đang đua trượt ván của họ ở một thành phố lớn']
#   ggtrans: ['đây là ngày trượt ván quốc gia trong thành phố', 'họ đang đứng trên ván và đi xuống phố', 'họ đang đua ván trượt ở một thành phố lớn']
#   gpt: ['hôm nay là ngày đi ván trượt quốc gia ở thành phố.', 'họ đang đứng trên ván và chạy xuống đường.', 'họ đang đua ván trượt trong một thành phố lớn.']
# =====================================
# ID: 4551001
# explanation: ['beautiful kits are flying in the sky at the event', 'there are many colorful kites being flown in the sky', 'there are many people have a great time on the field behind the dinosaur']
# Argmax: những chiếc diều đẹp đang bay trên bầu trời tại sự kiện; có rất nhiều con diều đầy màu sắc đang bay trên bầu trời; có rất nhiều người đang có khoảng thời gian vui vẻ trên sân phía sau con khủng long
# Sampling: những con diều đẹp đang bay trên bầu trời tại sự kiện; có nhiều chiếc diều nhiều màu sắc đang bay trên bầu trời; có rất nhiều người đang vui vẻ trên cánh đồng phía sau khủng long
# Translation:
#   vinai: ['bộ dụng cụ đẹp đang bay trên bầu trời tại sự kiện này', 'có rất nhiều diều đầy màu sắc đang bay trên bầu trời', 'có rất nhiều người có một thời gian tuyệt vời trên các lĩnh vực đằng sau những con khủng long']
#   gemini: ['những con diều đẹp đang bay trên bầu trời tại sự kiện', 'có rất nhiều con diều nhiều màu sắc đang được thả trên bầu trời', 'có rất nhiều người đang vui vẻ trên cánh đồng phía sau khủng long']
#   ggtrans: ['bộ dụng cụ xinh đẹp đang bay trên bầu trời tại sự kiện', 'có rất nhiều con diều đầy màu sắc đang bay trên bầu trời', 'có rất nhiều người đang có khoảng thời gian vui vẻ trên sân phía sau con khủng long']
#   gpt: ['những chiếc diều đẹp đang bay trên bầu trời tại sự kiện', 'có nhiều chiếc diều nhiều màu sắc đang bay trên bầu trời', 'có nhiều người đang có một thời gian tuyệt vời trên cánh đồng phía sau con khủng long']
# =====================================
# ID: 306733003
# explanation: ['baths and showers are taken in bathrooms', 'there is a tub and shower', 'there is a bath tub and a sink to the left of the tub']
# Argmax: bồn tắm và vòi hoa sen được thực hiện trong phòng tắm; có một bồn tắm và vòi hoa sen; có một bồn tắm và một bồn rửa ở bên trái bồn tắm
# Sampling: bồn tắm và vòi hoa sen được thực hiện trong phòng tắm; có bồn tắm và vòi hoa sen; có bồn tắm và bồn rửa bên trái bồn tắm
# Translation:
#   vinai: ['Phòng tắm và vòi hoa sen được thực hiện trong phòng tắm.', 'có bồn tắm và vòi hoa sen', 'có bồn tắm và bồn rửa ở bên trái bồn tắm']
#   gemini: ['tắm và tắm vòi sen được thực hiện trong phòng tắm', 'có bồn tắm và vòi sen', 'có bồn tắm và bồn rửa bên trái bồn tắm']
#   ggtrans: ['bồn tắm và vòi hoa sen được thực hiện trong phòng tắm', 'có một bồn tắm và vòi hoa sen', 'có một bồn tắm và một bồn rửa ở bên trái bồn tắm']
#   gpt: ['tắm và tắm vòi sen được thực hiện trong phòng tắm', 'có một bồn tắm và vòi sen', 'có một bồn tắm và một chậu rửa bên trái bồn tắm']
# =====================================
# ID: 473075002
# explanation: ['snow is necessary to snowboard', 'there is a bunch of snow on the ground', 'the land is covered in snow']
# Argmax: tuyết là cần thiết để trượt ván trên tuyết; có rất nhiều tuyết trên mặt đất; mặt đất được phủ đầy tuyết
# Sampling: tuyết là cần thiết để trượt tuyết; có một đống tuyết trên mặt đất; Đất phủ đầy tuyết.
# Translation:
#   vinai: ['tuyết là cần thiết để trượt tuyết', 'Có một đống tuyết trên mặt đất.', 'Đất phủ đầy tuyết.']
#   gemini: ['tuyết là cần thiết để trượt tuyết', 'có rất nhiều tuyết trên mặt đất', 'đất được bao phủ bởi tuyết']
#   ggtrans: ['tuyết là cần thiết để trượt tuyết', 'có một đống tuyết trên mặt đất', 'vùng đất được bao phủ trong tuyết']
#   gpt: ['tuyết là cần thiết để trượt ván trên tuyết', 'có rất nhiều tuyết trên mặt đất', 'mặt đất được phủ đầy tuyết']
# =====================================
# ID: 543836002
# explanation: ['there is a book laying open next to him', 'there is a book upside down on the other side of the bed', 'there is an opened book next to him']
# Argmax: có một cuốn sách đang mở bên cạnh anh ấy; Có một cuốn sách lộn ngược ở phía bên kia giường.; có một cuốn sách đang mở bên cạnh anh ấy
# Sampling: có một cuốn sách nằm mở cạnh anh ấy; có một cuốn sách lộn ngược ở phía bên kia giường; Có một cuốn sách mở bên cạnh anh ta.
# Translation:
#   vinai: ['Có một quyển sách đang mở ra cạnh anh ấy.', 'Có một cuốn sách lộn ngược ở phía bên kia giường.', 'Có một cuốn sách mở bên cạnh anh ta.']
#   gemini: ['có một cuốn sách nằm mở cạnh anh ấy', 'có một cuốn sách úp ngược ở phía bên kia giường', 'có một cuốn sách mở cạnh anh ấy']
#   ggtrans: ['có một cuốn sách đang mở bên cạnh anh ấy', 'có một cuốn sách lộn ngược ở phía bên kia giường', 'có một cuốn sách đang mở bên cạnh anh ấy']
#   gpt: ['có một cuốn sách đặt mở bên cạnh anh ấy', 'có một cuốn sách lộn ngược ở phía bên kia của giường', 'có một cuốn sách mở bên cạnh anh ấy']
# =====================================
# ID: 434873000
# explanation: ['there is a lot of sand', 'there are people walking around on sand', 'he is playing sand volleyball in the sand']
# Argmax: Có rất nhiều cát.; có những người đang đi dạo trên cát; anh ta đang chơi bóng chuyền bãi biển trên cát
# Sampling: có rất nhiều cát; có người đi bộ trên cát; Nó đang chơi bóng chuyền trên cát.
# Translation:
#   vinai: ['Có rất nhiều cát.', 'có những người đi dạo trên cát', 'Nó đang chơi bóng chuyền trên cát.']
#   gemini: ['có rất nhiều cát', 'có người đi bộ trên cát', 'anh ta đang chơi bóng chuyền bãi biển trên cát']
#   ggtrans: ['có rất nhiều cát', 'có những người đang đi dạo trên cát', 'anh ấy đang chơi bóng chuyền trên cát']
#   gpt: ['có rất nhiều cát', 'có người đi lại trên cát', 'anh ấy đang chơi bóng chuyền cát trên cát']
# =====================================
# ID: 284064003
# explanation: ['the man is holding a racket up', 'he has a racket and a tennis ball', 'the man is swinging at a tennis ball with a racket']
# Argmax: người đàn ông đang cầm cây vợt lên; anh ấy có một cây vợt và một quả bóng tennis; người đàn ông đang vung vợt vào quả bóng tennis
# Sampling: người đàn ông đang cầm cây vợt lên; anh ấy có một cây vợt và một quả bóng tennis; người đàn ông đang vung vợt vào một quả bóng quần vợt
# Translation:
#   vinai: ['người đàn ông đang cầm một vợt lên', 'Anh ta có vợt và bóng tennis.', 'người đàn ông đang đu tại một quả bóng tennis với một vợt']
#   gemini: ['người đàn ông đang cầm một cây vợt', 'anh ấy có một cây vợt và một quả bóng tennis', 'người đàn ông đang vung một quả bóng tennis bằng một cây vợt']
#   ggtrans: ['người đàn ông đang cầm vợt lên', 'anh ấy có một cây vợt và một quả bóng tennis', 'người đàn ông đang vung vợt vào quả bóng tennis']
#   gpt: ['người đàn ông đang cầm cây vợt lên', 'anh ấy có một cây vợt và một quả bóng quần vợt', 'người đàn ông đang vung vợt vào một quả bóng quần vợt']
# =====================================
# ID: 381870001
# explanation: ['the elephant wranglers are all wearing ponchos and carrying umbrellas and the ground is wet', 'the ground is wet and people are using umbrellas', 'the cement is wet and you can see it reflecting the daylight']
# Argmax: Những người đánh voi đều mặc áo ponchos và mang ô, và mặt đất ẩm ướt.; mặt đất ẩm ướt và mọi người đang sử dụng ô dù; Xi măng ướt và bạn có thể thấy nó phản chiếu ánh sáng ban ngày.
# Sampling: những người bắt voi đều mặc áo poncho và mang ô và mặt đất ướt; mặt đất ẩm ướt và mọi người đang sử dụng ô; xi măng bị ướt và bạn có thể nhìn thấy nó phản chiếu ánh sáng ban ngày
# Translation:
#   vinai: ['Những người đánh voi đều mặc áo ponchos và mang ô, và mặt đất ẩm ướt.', 'mặt đất ẩm ướt và mọi người đang sử dụng ô dù', 'Xi măng ướt và bạn có thể thấy nó phản chiếu ánh sáng ban ngày.']
#   gemini: ['những người huấn luyện voi đều mặc áo mưa và cầm ô và mặt đất ẩm ướt', 'mặt đất ẩm ướt và mọi người đang sử dụng ô', 'xi măng bị ướt và bạn có thể nhìn thấy nó phản chiếu ánh sáng ban ngày']
#   ggtrans: ['những người bắt voi đều mặc áo poncho và mang ô và mặt đất ướt', 'mặt đất ẩm ướt và mọi người đang sử dụng ô', 'Xi măng ướt và bạn có thể thấy nó phản chiếu ánh sáng ban ngày']
#   gpt: ['các người chăm sóc voi đều đang mặc áo poncho và cầm ô, và mặt đất ướt.', 'mặt đất ướt và mọi người đang sử dụng ô.', 'mặt đường ướt và bạn có thể thấy nó phản chiếu ánh sáng ban ngày.']
# =====================================
# ID: 92894000
# explanation: ['there are player at home plate', 'there is a batter, catcher and umpire waiting at home plate', 'there is a batter and a catcher']
# Argmax: có cầu thủ ở sân nhà; có người đánh bóng, người bắt bóng và trọng tài đang đợi ở sân nhà; có một người đánh bóng và một người bắt bóng
# Sampling: có cầu thủ ở bệ nhà; có người đánh bóng, người bắt bóng và trọng tài đang chờ ở vị trí sân nhà; có một người đánh bóng và một người bắt bóng
# Translation:
#   vinai: ['có cầu thủ ở tấm sân nhà', 'có một cầu thủ đánh bóng, bắt bóng và trọng tài đang chờ ở sân nhà', 'có một cầu thủ đập bóng và một cầu thủ bắt bóng']
#   gemini: ['có cầu thủ ở vị trí sân nhà', 'có người đánh bóng, người bắt bóng và trọng tài đang chờ ở vị trí sân nhà', 'có người đánh bóng và người bắt bóng']
#   ggtrans: ['có cầu thủ ở sân nhà', 'có người đánh bóng, người bắt bóng và trọng tài đang đợi ở sân nhà', 'có một người đánh bóng và một người bắt bóng']
#   gpt: ['có cầu thủ ở bệ nhà', 'có một người đánh bóng, một người bắt bóng và một trọng tài đang chờ ở bệ nhà', 'có một người đánh bóng và một người bắt bóng']
# =====================================
# ID: 119026001
# explanation: ['the logo is on the top', 'the logo is on the phone', 'the logo is visible across the phone']
# Argmax: logo ở trên cùng; biểu tượng trên điện thoại; biểu tượng có thể nhìn thấy trên khắp điện thoại
# Sampling: logo ở trên cùng; biểu tượng ở trên điện thoại; logo có thể nhìn thấy trên điện thoại
# Translation:
#   vinai: ['logo ở trên cùng', 'biểu tượng trên điện thoại', 'biểu tượng có thể nhìn thấy trên điện thoại']
#   gemini: ['biểu tượng ở trên đỉnh', 'biểu tượng ở trên điện thoại', 'biểu tượng có thể nhìn thấy trên khắp điện thoại']
#   ggtrans: ['logo ở trên cùng', 'logo ở trên điện thoại', 'logo có thể nhìn thấy trên điện thoại']
#   gpt: ['logo ở trên cùng', 'logo nằm trên điện thoại', 'logo có thể nhìn thấy trên điện thoại']
# =====================================
# ID: 41488000
# explanation: ['there is a sign that prohibits them from entering the road', 'there is a big white sign reading "no trucks"', 'they are explicitly forbidden by sign']
# Argmax: có một biển báo cấm họ đi vào đường; có một tấm biển lớn màu trắng ghi "cấm xe tải"; họ bị cấm một cách rõ ràng bằng dấu hiệu
# Sampling: Có một biển báo cấm chúng vào đường; có một tấm biển lớn màu trắng ghi "không có xe tải"; Chúng bị cấm rõ ràng bằng biển báo
# Translation:
#   vinai: ['có một dấu hiệu cấm họ vào đường', 'có một tấm biển lớn màu trắng ghi "không có xe tải"', 'chúng bị cấm rõ ràng bằng dấu hiệu']
#   gemini: ['có một biển báo cấm chúng vào đường', 'có một biển báo màu trắng lớn ghi "cấm xe tải"', 'chúng bị cấm rõ ràng bởi biển báo']
#   ggtrans: ['có một biển báo cấm họ đi vào đường', 'có một tấm biển lớn màu trắng ghi "cấm xe tải"', 'họ bị cấm một cách rõ ràng bằng dấu hiệu']
#   gpt: ['Có một biển báo cấm chúng vào đường', 'Có một biển báo lớn màu trắng ghi "cấm xe tải"', 'Chúng bị cấm rõ ràng bằng biển báo']
# =====================================
# ID: 57150002
# explanation: ['she is holding onto a teddy bear', 'she is very happy to have gotten a teddy bear', 'the corner of her lips are turned upward']
# Argmax: Cô ấy đang giữ một con gấu bông.; cô ấy rất vui khi có được một con gấu bông; khóe môi cô ấy nhếch lên
# Sampling: cô ấy đang giữ một con gấu bông; Cô ấy rất vui khi có được một con gấu bông.; góc của đôi môi của cô được bật lên
# Translation:
#   vinai: ['cô ấy đang giữ một con gấu bông', 'Cô ấy rất vui khi có được một con gấu bông.', 'góc của đôi môi của cô được bật lên']
#   gemini: ['cô ấy đang cầm một con gấu bông', 'cô ấy rất vui khi được tặng một con gấu bông', 'góc môi của cô ấy được hướng lên trên']
#   ggtrans: ['cô ấy đang ôm một con gấu bông', 'cô ấy rất vui khi có được một con gấu bông', 'khóe môi cô ấy nhếch lên']
#   gpt: ['Cô ấy đang giữ một con gấu bông.', 'Cô ấy rất hạnh phúc vì đã có một con gấu bông.', 'Đuôi môi của cô ấy được hướng lên trên.']
# =====================================
# ID: 281500005
# explanation: ['the man is holding a racket and standing beside a tennis court', 'the man in white is waiting to swat a ball', 'a man is holding a tennis racket']
# Argmax: người đàn ông đang cầm vợt và đứng cạnh sân tennis; người đàn ông mặc đồ trắng đang chờ đập bóng; một người đàn ông đang cầm vợt tennis
# Sampling: người đàn ông đang cầm một cây vợt và đứng bên cạnh một sân tennis; người đàn ông mặc đồ trắng đang chờ đập bóng; một người đàn ông đang cầm vợt tennis
# Translation:
#   vinai: ['người đàn ông đang cầm một cây vợt và đứng bên cạnh một sân tennis', 'người đàn ông mặc đồ trắng đang chờ để đập một quả bóng', 'một người đàn ông đang cầm một cây vợt tennis']
#   gemini: ['người đàn ông đang cầm vợt và đứng bên cạnh sân quần vợt', 'người đàn ông mặc áo trắng đang chờ để đánh bóng', 'một người đàn ông đang cầm vợt quần vợt']
#   ggtrans: ['người đàn ông đang cầm vợt và đứng cạnh sân tennis', 'người đàn ông mặc đồ trắng đang chờ đập bóng', 'một người đàn ông đang cầm vợt tennis']
#   gpt: ['người đàn ông đang cầm một cái vợt và đứng bên cạnh một sân quần vợt', 'người đàn ông mặc áo trắng đang chờ để đánh bóng', 'một người đàn ông đang cầm một cái vợt quần vợt']
# =====================================
# ID: 287545001
# explanation: ['the giraffe is standing inside of a building', 'the giraffes are in an enclosure', 'there are giraffes inside an enclosure']
# Argmax: con hươu cao cổ đang đứng bên trong một tòa nhà; hươu cao cổ đang ở trong chuồng; có những con hươu cao cổ bên trong một chuồng
# Sampling: hươu cao cổ đang đứng bên trong một tòa nhà; các hươu cao cổ đang ở trong một khu nuôi nhốt; có những con hươu cao cổ bên trong một chuồng
# Translation:
#   vinai: ['hươu cao cổ đang đứng bên trong một tòa nhà', 'những con hươu cao cổ đang trong một bao vây', 'có hươu cao cổ bên trong một bao vây']
#   gemini: ['con hươu cao cổ đang đứng trong một tòa nhà', 'những con hươu cao cổ ở trong một chuồng', 'có những con hươu cao cổ bên trong một chuồng']
#   ggtrans: ['con hươu cao cổ đang đứng bên trong một tòa nhà', 'hươu cao cổ đang ở trong chuồng', 'có hươu cao cổ bên trong chuồng']
#   gpt: ['hươu cao cổ đang đứng bên trong một tòa nhà', 'các hươu cao cổ đang ở trong một khu nuôi nhốt', 'có hươu cao cổ bên trong một khu nuôi nhốt']
# =====================================
# ID: 176595002
# explanation: ['she has glasses placed on top of her head', 'the reflective accessory is on top of her head', 'there are sunglasses sitting on her head']
# Argmax: cô ấy có một cặp kính đặt trên đầu.; phụ kiện phản chiếu ở trên đầu cô ấy; Có kính râm trên đầu cô ấy.
# Sampling: cô ấy đeo kính trên đầu; phụ kiện phản chiếu ở trên đầu cô ấy.; Có kính râm trên đầu cô ấy.
# Translation:
#   vinai: ['Cô ấy đeo kính trên đỉnh đầu.', 'phụ kiện phản chiếu là trên đỉnh đầu của cô ấy', 'Có kính râm trên đầu cô ấy.']
#   gemini: ['cô ấy có kính đặt trên đầu', 'phụ kiện phản chiếu nằm trên đầu cô ấy', 'có kính râm đặt trên đầu cô ấy']
#   ggtrans: ['cô ấy đeo kính trên đầu', 'phụ kiện phản chiếu ở trên đầu cô ấy', 'có chiếc kính râm ngồi trên đầu cô ấy']
#   gpt: ['cô ấy có một cặp kính đặt trên đầu.', 'phụ kiện phản chiếu ở trên đầu cô ấy.', 'có một cặp kính râm nằm trên đầu cô ấy.']
# =====================================
# ID: 527962001
# explanation: ['there are no cars or people on the street', 'there are no people or cars around', 'the street is empty of people']
# Argmax: không có xe hơi hay người trên đường; không có người hoặc xe xung quanh; đường phố vắng người
# Sampling: không có xe hơi hay người trên đường; không có người hoặc xe xung quanh; đường phố vắng người
# Translation:
#   vinai: ['Không có xe hay người trên đường.', 'không có người hay xe cộ xung quanh', 'Đường phố vắng tanh người.']
#   gemini: ['không có xe cộ hoặc người đi bộ trên đường', 'không có người hoặc xe cộ xung quanh', 'đường phố trống vắng người']
#   ggtrans: ['không có xe hơi hay người trên đường', 'không có người hoặc xe xung quanh', 'đường phố vắng người']
#   gpt: ['không có xe cộ hay người trên đường', 'không có người hay xe cộ xung quanh', 'đường phố vắng người']
# =====================================
# ID: 400981000
# explanation: ['there is a net diving the court', 'they are hitting a tennis ball on a court', 'there are two people on a tennis court holding tennis racketsand and there is a sign that says "us open"']
# Argmax: có một cái lưới chia tách sân; họ đang đánh một quả bóng tennis trên sân; có hai người trên sân quần vợt cầm vợt quần vợt và có một biển báo ghi "us open"
# Sampling: có một cái lưới chia tách sân; họ đang đánh một quả bóng tennis trên sân; có hai người trên sân tennis đang cầm vợt tennis và có một tấm biển ghi "chúng tôi mở cửa"
# Translation:
#   vinai: ['có một lưới lặn tòa án', 'họ đang đánh một quả bóng tennis trên sân', 'có hai người trên sân tennis đang cầm vợt tennisvà có một tấm biển ghi "chúng tôi mở"']
#   gemini: ['có một lưới phân chia sân', 'họ đang đánh bóng tennis trên sân', 'có hai người trên sân quần vợt cầm vợt tennis và có một biển báo ghi "us open"']
#   ggtrans: ['có một cái lưới lặn xuống sân', 'họ đang đánh một quả bóng tennis trên sân', 'có hai người trên sân tennis đang cầm vợt tennis và có một tấm biển ghi "chúng tôi mở cửa"']
#   gpt: ['có một cái lưới chia tách sân', 'họ đang đánh một quả bóng quần vợt trên sân', 'có hai người trên sân quần vợt cầm vợt quần vợt và có một biển báo ghi "us open"']
# =====================================
# ID: 400794001
# explanation: ['he is holding food', 'he has a bit of pizza in his hand', 'he is looking at a piece of food in his hand']
# Argmax: anh ấy đang cầm thức ăn; Anh ta có một miếng pizza trong tay.; anh ấy đang nhìn vào một miếng thức ăn trong tay mình
# Sampling: anh ấy đang cầm thức ăn; anh ấy có một ít bánh pizza trong tay; anh ấy đang nhìn vào miếng thức ăn trên tay
# Translation:
#   vinai: ['Nó đang cầm thức ăn.', 'Anh ta có một miếng pizza trong tay.', 'ông đang nhìn vào một miếng thức ăn trong tay của mình']
#   gemini: ['anh ấy đang cầm thức ăn', 'anh ấy có một miếng pizza trong tay', 'anh ấy đang nhìn vào một miếng thức ăn trong tay mình']
#   ggtrans: ['anh ấy đang cầm thức ăn', 'anh ấy có một ít bánh pizza trong tay', 'anh ấy đang nhìn vào miếng thức ăn trên tay']
#   gpt: ['anh ấy đang cầm thức ăn', 'anh ấy có một miếng pizza trong tay', 'anh ấy đang nhìn vào một miếng thức ăn trong tay']
# =====================================
# ID: 33005000
# explanation: ['the man is swinging a tennis racket', 'he is holding a racket', 'the man is hitting a yellow ball']
# Argmax: người đàn ông đang vung vợt tennis; anh ấy đang cầm một cây vợt; người đàn ông đang đánh một quả bóng màu vàng
# Sampling: người đàn ông đang vung vợt tennis; anh ấy đang cầm một cây vợt; người đàn ông đang đánh một quả bóng màu vàng
# Translation:
#   vinai: ['Người đàn ông đang vung vợt tennis.', 'Hắn đang cầm vợt.', 'Anh ta đang đánh một quả bóng vàng.']
#   gemini: ['người đàn ông đang vung vợt tennis', 'anh ta đang cầm vợt', 'người đàn ông đang đánh một quả bóng màu vàng']
#   ggtrans: ['người đàn ông đang vung vợt tennis', 'anh ấy đang cầm một cây vợt', 'người đàn ông đang đánh một quả bóng màu vàng']
#   gpt: ['người đàn ông đang vung một cây vợt tennis', 'anh ấy đang cầm một cây vợt', 'người đàn ông đang đánh một quả bóng màu vàng']
# =====================================
# ID: 255662000
# explanation: ['he appears to be at ease on the horse', 'he is smiling while is on the animal', 'he is on top of a horse on the beach']
# Argmax: Anh ta có vẻ thoải mái trên lưng ngựa.; anh ấy đang mỉm cười khi ở trên con vật; Anh ta đang cưỡi ngựa trên bãi biển.
# Sampling: anh ấy có vẻ thoải mái trên con ngựa; Nó đang mỉm cười khi ở trên con vật.; Anh ta đang cưỡi ngựa trên bãi biển.
# Translation:
#   vinai: ['Anh ta có vẻ thoải mái trên lưng ngựa.', 'Nó đang mỉm cười khi ở trên con vật.', 'Anh ta đang cưỡi ngựa trên bãi biển.']
#   gemini: ['anh ấy có vẻ thoải mái trên lưng ngựa', 'anh ấy đang cười khi ở trên lưng con vật', 'anh ấy đang ở trên lưng ngựa trên bãi biển']
#   ggtrans: ['anh ta có vẻ thoải mái trên ngựa', 'anh ấy đang mỉm cười khi ở trên con vật', 'anh ấy đang cưỡi ngựa trên bãi biển']
#   gpt: ['anh ấy có vẻ thoải mái trên con ngựa', 'anh ấy đang mỉm cười trong khi đang trên con vật', 'anh ấy đang ngồi trên một con ngựa trên bãi biển']
# =====================================
# ID: 566264000
# explanation: ["it's entire body is under the water", 'the dog is out in the middle of the water', 'his head is just above water in a lake']
# Argmax: toàn bộ cơ thể nó ở dưới nước; Con chó đang ở giữa nước.; đầu của nó chỉ vừa trên mặt nước trong một cái hồ
# Sampling: Toàn bộ cơ thể nằm dưới nước.; con chó đang ở giữa nước; đầu anh ấy ở ngay trên mặt nước trong hồ
# Translation:
#   vinai: ['Toàn bộ cơ thể nằm dưới nước.', 'Con chó đang ở giữa nước.', 'Đầu anh ta ở ngay trên mặt nước trong một cái hồ.']
#   gemini: ['toàn bộ cơ thể của nó nằm dưới nước', 'con chó ở giữa hồ', 'đầu của nó chỉ nhô lên khỏi mặt nước trong hồ']
#   ggtrans: ['toàn bộ cơ thể nó ở dưới nước', 'con chó đang ở giữa nước', 'đầu anh ấy ở ngay trên mặt nước trong hồ']
#   gpt: ['toàn bộ cơ thể của nó ở dưới nước', 'chó ở giữa mặt nước', 'đầu của nó chỉ vừa trên mặt nước trong một cái hồ']
# =====================================
# ID: 448511008
# explanation: ['the plate is covered in vegetables, beans and grains', 'there is no meat on the plate', 'there is no meat present']
# Argmax: đĩa được phủ đầy rau, đậu và ngũ cốc; Không có thịt trên đĩa.; không có thịt nào hiện diện
# Sampling: đĩa được bao phủ trong rau, đậu và ngũ cốc; không có thịt trên đĩa; không có thịt hiện diện
# Translation:
#   vinai: ['đĩa được bao phủ trong rau, đậu và ngũ cốc', 'Không có thịt trên đĩa.', 'không có thịt hiện nay']
#   gemini: ['cái đĩa được phủ đầy rau, đậu và ngũ cốc', 'không có thịt trên đĩa', 'không có thịt nào hiện diện']
#   ggtrans: ['đĩa được phủ đầy rau, đậu và ngũ cốc', 'không có thịt trên đĩa', 'không có thịt hiện tại']
#   gpt: ['đĩa được phủ đầy rau, đậu và ngũ cốc', 'không có thịt trên đĩa', 'không có thịt hiện diện']
# =====================================
# ID: 52166001
# explanation: ['there are many people standing around watching the skiier', 'there are many people gathered around watching a single person', 'there are many people gathered watching someone perofrm']
# Argmax: có rất nhiều người đứng xung quanh xem người trượt tuyết; có rất nhiều người tụ tập xung quanh xem một người duy nhất; có rất nhiều người tụ tập xem ai đó biểu diễn
# Sampling: có rất nhiều người đứng xung quanh xem người trượt tuyết; có rất nhiều người tập trung xung quanh để xem một người; có rất nhiều người tập trung để xem ai đó biểu diễn
# Translation:
#   vinai: ['có rất nhiều người đứng xung quanh xem skiier', 'có rất nhiều người tụ tập xung quanh xem một người duy nhất', 'có rất nhiều người tụ tập xem ai đó perofrm']
#   gemini: ['có rất nhiều người đứng xung quanh để xem người trượt tuyết', 'có rất nhiều người tập trung xung quanh để xem một người', 'có rất nhiều người tập trung để xem ai đó biểu diễn']
#   ggtrans: ['có rất nhiều người đứng xung quanh xem người trượt tuyết', 'có rất nhiều người tụ tập xung quanh để xem một người', 'có rất nhiều người tụ tập xem ai đó biểu diễn']
#   gpt: ['có nhiều người đứng xung quanh xem người trượt tuyết.', 'có nhiều người tụ tập quanh xem một người duy nhất.', 'có nhiều người tụ tập xem ai đó biểu diễn.']
# =====================================
# ID: 316161001
# explanation: ['he is taking pecks out of a fruit in the tree', 'it is poking at a piece of fruit with its beak', 'it is pecking at a fruit on a tree']
# Argmax: Nó đang mổ một trái cây trên cây.; nó đang dùng mỏ chọc vào một miếng trái cây; nó đang mổ vào một quả trên cây
# Sampling: nó đang mổ những miếng trái cây trên cây; nó đang dùng mỏ để chọc vào một miếng trái cây; nó đang mổ quả trên cây
# Translation:
#   vinai: ['Nó đang mổ một trái cây trên cây.', 'nó đang chọc vào một miếng trái cây với cái mỏ của nó', 'nó đang mổ vào một quả trên cây']
#   gemini: ['nó đang mổ những miếng trái cây trên cây', 'nó đang dùng mỏ để chọc vào một miếng trái cây', 'nó đang mổ một trái cây trên cây']
#   ggtrans: ['anh ấy đang mổ một quả trên cây', 'nó đang dùng mỏ chọc vào một miếng trái cây', 'nó đang mổ quả trên cây']
#   gpt: ['nó đang mổ vào một quả trên cây', 'nó đang chọc vào một miếng trái cây bằng mỏ của nó', 'nó đang mổ vào một quả trên cây']
# =====================================
# ID: 363831005
# explanation: ['the batter is swinging at a ball as the catcher and umpire look on from behind him', 'trimmed grass lines the dirt in the baseball diamond', 'a man is swinging a baseball bat on home base']
# Argmax: người đánh bóng đang vung gậy đánh bóng khi người bắt bóng và trọng tài nhìn từ phía sau; cỏ được cắt tỉa bao quanh đất trong sân bóng chày; một người đàn ông đang vung cây gậy bóng chày ở sân nhà
# ...
# Translation:
#   vinai: ['nó là một miếng thịt đỏ nấu chín', 'Thịt có màu nâu ở bên ngoài và màu đỏ bên trong', 'nó có thịt và màu nâu']
#   gemini: ['đây là một miếng thịt đỏ đã nấu chín', 'thịt có màu nâu bên ngoài và đỏ bên trong', 'nó có thịt và màu nâu']
#   ggtrans: ['đó là một miếng thịt đỏ nấu chín', 'thịt có màu nâu bên ngoài và màu đỏ bên trong', 'nó có nhiều thịt và màu nâu']
#   gpt: ['nó là một miếng thịt đỏ đã nấu chín', 'thịt có màu nâu bên ngoài và màu đỏ bên trong', 'nó có nhiều thịt và màu nâu']
# =====================================
# ID: 532983002
# explanation: ['the people are in the dining car of a train', "it's a long dining car", 'the seats are very narrowly placed inside of a rail car']
# Argmax: mọi người đang ở trong toa ăn của một chuyến tàu; đó là một toa nhà ăn dài; những chiếc ghế được đặt rất hẹp bên trong toa xe lửa
# Sampling: mọi người đang ở trong toa ăn của một chuyến tàu; đó là một toa ăn uống dài; những chiếc ghế được đặt rất hẹp bên trong toa xe lửa
# Translation:
#   vinai: ['mọi người đang ở trong toa ăn của một chuyến tàu', 'Đó là một chiếc xe ăn dài.', 'ghế ngồi được đặt rất hẹp bên trong một toa xe lửa']
#   gemini: ['những người này đang ở toa ăn của một đoàn tàu', 'đó là một toa ăn dài', 'những chỗ ngồi được đặt rất hẹp bên trong một toa xe lửa']
#   ggtrans: ['mọi người đang ở trong toa ăn của một chuyến tàu', 'đó là một toa ăn uống dài', 'những chiếc ghế được đặt rất hẹp bên trong toa xe lửa']
#   gpt: ['những người đang ở trong toa nhà ăn của một chiếc tàu', 'đó là một toa nhà ăn dài', 'các ghế được đặt rất chật bên trong một toa xe lửa']
# =====================================
# ID: 575544001
# explanation: ['it is an old style with a small engine', 'it looks kind of old', 'it is a very old motorcycle']
# Argmax: nó là một phong cách cũ với một động cơ nhỏ; Trông có vẻ cũ rồi.; nó là một chiếc xe máy rất cũ
# Sampling: nó là một kiểu cũ với động cơ nhỏ; nó trông hơi cũ; đây là một chiếc xe máy rất cũ
# Translation:
#   vinai: ['nó là một phong cách cũ với một động cơ nhỏ', 'Trông có vẻ cũ rồi.', 'nó là một chiếc xe máy rất cũ']
#   gemini: ['nó là một kiểu cũ với động cơ nhỏ', 'nó trông có vẻ cũ', 'nó là một chiếc xe máy rất cũ']
#   ggtrans: ['nó là kiểu cũ với động cơ nhỏ', 'nó trông hơi cũ', 'nó là một chiếc xe máy rất cũ']
#   gpt: ['nó có kiểu dáng cũ với động cơ nhỏ', 'nó có vẻ hơi cũ', 'đây là một chiếc xe máy rất cũ']
# =====================================
# ID: 553083000
# explanation: ['it has soft puffy balls of hair', 'it has really curly fur', 'it has very puffy fur and a pointy nose']
# Argmax: nó có những búi lông mềm và phồng.; nó có bộ lông rất xoăn; nó có bộ lông rất phồng và một chiếc mũi nhọn.
# Sampling: nó có những búi lông mềm và phồng.; nó có lông xoăn thật sự; nó có lông rất sưng húp và mũi nhọn
# Translation:
#   vinai: ['nó có những quả bóng mềm mại của tóc', 'nó có lông thực sự xoăn', 'nó có lông rất sưng húp và mũi nhọn']
#   gemini: ['nó có những quả bóng lông mềm mại', 'nó có lông xoăn thật sự', 'nó có bộ lông rất xù và mũi nhọn']
#   ggtrans: ['nó có những lọn tóc phồng mềm mại', 'nó có bộ lông rất xoăn', 'nó có bộ lông rất xù và cái mũi nhọn']
#   gpt: ['nó có những búi lông mềm và phồng.', 'nó có bộ lông rất xoăn.', 'nó có bộ lông rất phồng và một chiếc mũi nhọn.']
# =====================================
# ID: 93685003
# explanation: ['there is a logo on the bottom', 'there are black logo stickers on the surfboard', 'there are deals on the bottom of the surfboard']
# Argmax: có một logo ở phía dưới; có những miếng dán logo màu đen trên ván lướt sóng; có những hình dán ở đáy của ván lướt sóng
# Sampling: có một logo ở phía dưới; có dán logo màu đen trên ván lướt sóng; có những hình dán ở đáy của ván lướt sóng
# Translation:
#   vinai: ['có một logo ở phía dưới', 'có dán logo màu đen trên ván lướt sóng', 'có những thỏa thuận ở dưới cùng của ván lướt sóng']
#   gemini: ['có một logo ở dưới cùng', 'có những nhãn dán logo màu đen trên ván lướt sóng', 'có các giao dịch ở dưới cùng của ván lướt sóng']
#   ggtrans: ['có một logo ở phía dưới', 'có những miếng dán logo màu đen trên ván lướt sóng', 'có những giao dịch ở dưới cùng của ván lướt sóng']
#   gpt: ['có một logo ở đáy', 'có những hình dán logo màu đen trên ván lướt sóng', 'có những hình dán ở đáy của ván lướt sóng']
# =====================================
# ID: 143359001
# explanation: ['he jumped on it', 'he is on top of a board with wheels', 'he is hovering over the board as it flips']
# Argmax: cậu ấy đã nhảy lên đó; cậu ấy đang ở trên một tấm ván có bánh xe; anh ấy đang lơ lửng trên bảng khi nó lật
# Sampling: cậu ấy đã nhảy lên đó; anh ấy đang ở trên một tấm ván có bánh xe; cậu ấy đang lơ lửng trên ván khi nó lật
# Translation:
#   vinai: ['Anh ta nhảy lên nó.', 'Nó đang ở trên một tấm ván có bánh xe.', 'Ông đang lơ lửng trên bảng khi nó lật']
#   gemini: ['cậu ấy nhảy lên nó', 'cậu ấy đang ở trên một tấm ván có bánh xe', 'cậu ấy đang lơ lửng trên ván khi nó lật']
#   ggtrans: ['anh ấy đã nhảy lên nó', 'anh ấy đang ở trên một tấm ván có bánh xe', 'anh ấy đang lơ lửng trên bảng khi nó lật']
#   gpt: ['cậu ấy đã nhảy lên đó', 'cậu ấy đang đứng trên một cái ván có bánh xe', 'cậu ấy đang lơ lửng trên ván khi nó lộn ngược']
# =====================================
# ID: 68628000
# explanation: ['the man is in the air, with the skateboard flipping', 'he is jumping the stairs on his skateboard', 'he is doing tricks with his skateboard']
# Argmax: người đàn ông ở trên không với chiếc ván trượt đang lật; anh ấy đang nhảy cầu thang trên ván trượt của mình; ông ấy đang thực hiện các mẹo với cái ván trượt của mình
# Sampling: người đàn ông đang ở trên không trung, với ván trượt đang lật; ông ấy đang nhảy qua cầu thang trên cái ván trượt của mình; ông ấy đang thực hiện các mẹo với cái ván trượt của mình
# Translation:
#   vinai: ['người đàn ông là trong không khí, với lật ván trượt', 'anh ấy đang nhảy cầu thang trên ván trượt của mình', 'Nó đang nghịch ván trượt của nó.']
#   gemini: ['người đàn ông đang ở trên không trung, với ván trượt đang lật', 'anh ấy đang nhảy cầu thang bằng ván trượt của mình', 'anh ấy đang biểu diễn các trò chơi khéo léo với ván trượt của mình']
#   ggtrans: ['người đàn ông ở trên không với chiếc ván trượt đang lật', 'anh ấy đang nhảy cầu thang trên ván trượt của mình', 'anh ấy đang làm trò với ván trượt của mình']
#   gpt: ['người đàn ông đang ở trên không, với cái ván trượt đang lật', 'ông ấy đang nhảy qua cầu thang trên cái ván trượt của mình', 'ông ấy đang thực hiện các mẹo với cái ván trượt của mình']
# =====================================
# ID: 446861004
# explanation: ['the ground is dry and there are only a few clouds in the sky', 'the ground is dry and the clouds are only white', 'the sky is blue with no rain clouds in sight']
# Argmax: Mặt đất khô và chỉ có vài đám mây trên bầu trời.; mặt đất khô và mây chỉ trắng; bầu trời trong xanh không có đám mây mưa nào trong tầm mắt
# Sampling: mặt đất khô ráo và chỉ có một vài đám mây trên bầu trời; mặt đất khô và các đám mây chỉ toàn màu trắng; bầu trời xanh và không có mây mưa
# Translation:
#   vinai: ['Mặt đất khô và chỉ có vài đám mây trên bầu trời.', 'Mặt đất khô và những đám mây chỉ có màu trắng', 'Bầu trời trong xanh, không có mây mưa.']
#   gemini: ['mặt đất khô ráo và chỉ có một vài đám mây trên bầu trời', 'mặt đất khô ráo và những đám mây chỉ có màu trắng', 'bầu trời xanh và không có mây mưa']
#   ggtrans: ['mặt đất khô và chỉ có một vài đám mây trên bầu trời', 'mặt đất khô và mây chỉ trắng', 'bầu trời trong xanh không có đám mây mưa nào trong tầm mắt']
#   gpt: ['mặt đất khô và chỉ có vài đám mây trên bầu trời', 'mặt đất khô và các đám mây chỉ toàn màu trắng', 'bầu trời màu xanh không có đám mây mưa nào trong tầm nhìn']
# =====================================
# ID: 312559002
# explanation: ['the bus is in the middle of going from one side of the road, to the other and seems to be performing a u-turn', 'it needs to travel the other way', 'it is coming from one street to a new one']
# Argmax: xe buýt đang đi từ bên này sang bên kia đường và dường như đang quay đầu xe; nó cần di chuyển theo hướng ngược lại; nó đang đi từ đường này sang đường khác
# Sampling: xe buýt đang ở giữa việc di chuyển từ một bên đường sang bên kia và có vẻ như đang thực hiện một cú quay đầu; nó cần phải đi theo hướng khác; nó đang từ một con phố này sang một con phố mới
# Translation:
#   vinai: ['xe buýt đang ở giữa đi từ một bên đường, sang bên kia và dường như đang thực hiện một u-turn', 'nó cần di chuyển theo hướng khác.', 'nó đang đến từ một con đường đến một con đường mới']
#   gemini: ['xe buýt đang ở giữa việc đi từ một bên đường sang bên kia và dường như đang thực hiện một vòng xoay', 'nó cần phải đi theo hướng khác', 'nó đang đi từ một con phố này đến một con phố mới']
#   ggtrans: ['xe buýt đang đi từ bên này sang bên kia đường và dường như đang quay đầu xe', 'nó cần phải đi theo hướng khác', 'nó đang đi từ đường này sang đường khác']
#   gpt: ['xe buýt đang ở giữa việc di chuyển từ một bên đường sang bên kia và có vẻ như đang thực hiện một cú quay đầu', 'nó cần di chuyển theo hướng ngược lại', 'nó đang từ một con phố này sang một con phố mới']
# =====================================
# ID: 71618007
# explanation: ['you can see the water inside of the bowl', 'it is in the upright position', 'the inside of the toilet bowl can be seen']
# Argmax: bạn có thể thấy nước bên trong bát; nó ở vị trí thẳng đứng; có thể nhìn thấy bên trong bồn cầu
# Sampling: bạn có thể thấy nước bên trong bát; nó ở vị trí thẳng đứng; bên trong bồn cầu có thể được nhìn thấy
# Translation:
#   vinai: ['bạn có thể nhìn thấy nước bên trong bát', 'nó ở vị trí thẳng đứng', 'bên trong bồn cầu có thể được nhìn thấy']
#   gemini: ['bạn có thể nhìn thấy nước bên trong bồn cầu', 'nó ở vị trí dựng đứng', 'có thể nhìn thấy bên trong bồn cầu']
#   ggtrans: ['bạn có thể thấy nước bên trong bát', 'nó ở vị trí thẳng đứng', 'có thể nhìn thấy bên trong bồn cầu']
#   gpt: ['bạn có thể thấy nước bên trong bồn cầu', 'nó ở vị trí thẳng đứng', 'bên trong bồn cầu có thể được nhìn thấy']
# =====================================
# ID: 149592003
# explanation: ['the water is calm and no one is in it', 'the visible people are sitting on a bench enjoying the view of the water', 'the people in the picture are sitting on a bench']
# Argmax: Mặt nước tĩnh lặng và không có ai trong đó; những người có thể nhìn thấy đang ngồi trên một chiếc ghế dài tận hưởng khung cảnh của mặt nước; những người trong ảnh đang ngồi trên một chiếc ghế dài
# Sampling: nước yên tĩnh và không ai ở trong đó; những người có thể nhìn thấy đang ngồi trên ghế dài tận hưởng khung cảnh nước; Những người trong ảnh đang ngồi trên ghế dài.
# Translation:
#   vinai: ['Nước yên tĩnh và không có ai ở trong đó.', 'những người có thể nhìn thấy đang ngồi trên một chiếc ghế dài thưởng thức quan điểm của nước', 'Những người trong ảnh đang ngồi trên ghế dài.']
#   gemini: ['nước yên lặng và không ai ở trong đó', 'những người có thể nhìn thấy đang ngồi trên ghế dài tận hưởng khung cảnh nước', 'những người trong hình đang ngồi trên ghế dài']
#   ggtrans: ['Mặt nước tĩnh lặng và không có ai trong đó', 'những người có thể nhìn thấy đang ngồi trên một chiếc ghế dài tận hưởng khung cảnh của mặt nước', 'những người trong ảnh đang ngồi trên một chiếc ghế dài']
#   gpt: ['nước yên tĩnh và không ai ở trong đó', 'các người nhìn thấy đang ngồi trên ghế dài tận hưởng cảnh nước', 'các người trong bức ảnh đang ngồi trên ghế dài']
# =====================================
# ID: 17031004
# explanation: ['his jaw is all out of whack', 'he is chomping with his mouth', 'its bottom lip is rolled up']
# Argmax: hàm của nó bị lệch; anh ấy đang nhai bằng miệng; môi dưới của nó cuộn lên
# Sampling: hàm của nó bị lệch; nó đang nhai bằng miệng; môi dưới của nó được cuộn lên
# Translation:
#   vinai: ['hàm của ông là tất cả ra khỏi whack', 'Miệng nó đang nghẹn lại.', 'môi dưới của nó được cuộn lên']
#   gemini: ['hàm của nó bị lệch', 'nó đang nhai bằng miệng', 'môi dưới của nó cuộn lên']
#   ggtrans: ['quai hàm của anh ấy không còn phù hợp nữa', 'anh ấy đang nhai bằng miệng', 'môi dưới của nó cuộn lên']
#   gpt: ['xương hàm của nó bị lệch', 'nó đang nhai bằng miệng', 'môi dưới của nó bị cuộn lên']
# =====================================
# ID: 362712002
# explanation: ['the teens are wearing modern clothing', 'two boys are playing wii and are wearing modern clothing', 'the men are holding video game controllers']
# Argmax: thanh thiếu niên đang mặc quần áo hiện đại; hai cậu bé đang chơi wii và mặc quần áo hiện đại; những người đàn ông đang cầm bộ điều khiển trò chơi điện tử
# Sampling: các thiếu niên đang mặc quần áo hiện đại; hai cậu bé đang chơi wii và đang mặc quần áo hiện đại; những người đàn ông đang cầm điều khiển chơi game
# Translation:
#   vinai: ['các thiếu niên đang mặc quần áo hiện đại', 'hai chàng trai đang chơi wii và đang mặc quần áo hiện đại', 'Những người đàn ông đang cầm bộ điều khiển trò chơi điện tử.']
#   gemini: ['những thanh niên đang mặc quần áo hiện đại', 'hai chàng trai đang chơi wii và đang mặc quần áo hiện đại', 'những người đàn ông đang cầm điều khiển chơi game']
#   ggtrans: ['thanh thiếu niên đang mặc quần áo hiện đại', 'hai cậu bé đang chơi wii và mặc quần áo hiện đại', 'những người đàn ông đang cầm bộ điều khiển trò chơi điện tử']
#   gpt: ['các thanh thiếu niên đang mặc quần áo hiện đại', 'hai cậu bé đang chơi wii và đang mặc quần áo hiện đại', 'các người đàn ông đang cầm tay cầm chơi game']
# =====================================
# ID: 86125001
# explanation: ['the players are on a soccer pitch and wearing typical soccer uniforms, and kicking a soccer ball', 'they are running around on a field with a soccer ball', 'the players are kicking a soccer ball around']
# Argmax: các cầu thủ đang ở trên sân bóng đá và mặc đồng phục bóng đá điển hình và đá một quả bóng đá; họ đang chạy quanh sân với một quả bóng đá; các cầu thủ đang đá một quả bóng đá xung quanh
# Sampling: các cầu thủ đang ở trên sân bóng đá và mặc đồng phục bóng đá điển hình và đá một quả bóng đá; họ đang chạy xung quanh trên một sân với một quả bóng đá; các cầu thủ đang đá một quả bóng đá xung quanh
# Translation:
#   vinai: ['các cầu thủ đang ở trên một sân bóng đá và mặc đồng phục bóng đá điển hình, và đá một quả bóng đá', 'họ đang chạy xung quanh trên một lĩnh vực với một quả bóng đá', 'các cầu thủ đá một quả bóng đá xung quanh']
#   gemini: ['các cầu thủ đang ở sân bóng đá và mặc đồng phục bóng đá điển hình, và đá bóng', 'họ đang chạy quanh sân với một quả bóng đá', 'các cầu thủ đang đá bóng xung quanh']
#   ggtrans: ['các cầu thủ đang ở trên sân bóng đá và mặc đồng phục bóng đá điển hình và đá một quả bóng đá', 'họ đang chạy quanh sân với một quả bóng đá', 'các cầu thủ đang đá một quả bóng đá xung quanh']
#   gpt: ['các cầu thủ đang ở trên sân bóng đá và mặc đồng phục bóng đá điển hình, và đang đá một quả bóng đá', 'họ đang chạy xung quanh trên một sân với một quả bóng đá', 'các cầu thủ đang đá một quả bóng đá xung quanh']
# =====================================
# ID: 84540001
# explanation: ['one rider is a couple of feet behind the other', 'his wheel is further from the solid white line', 'the biker is closer to the line']
# Argmax: một tay đua đi sau người kia vài feet; bánh xe của anh ta cách vạch kẻ trắng liền mạch hơn; người đi xe đạp gần vạch kẻ hơn
# Sampling: một người đi xe đạp cách người kia vài feet; bánh xe của anh ấy ở xa vạch trắng liền hơn; người đi xe đạp gần vạch kẻ hơn
# Translation:
#   vinai: ['Một kỵ sĩ đi sau người kia vài bước chân.', 'bánh xe của mình là xa hơn từ dòng màu trắng rắn', 'Tay đua đã tới gần vạch đích hơn.']
#   gemini: ['một người đi xe đạp cách người kia vài feet', 'bánh xe của anh ta cách vạch kẻ trắng liền mạch hơn', 'người đi xe đạp gần vạch kẻ hơn']
#   ggtrans: ['một tay đua đi sau người kia vài feet', 'bánh xe của anh ấy ở xa vạch trắng liền hơn', 'người đi xe đạp đang ở gần vạch hơn']
#   gpt: ['một người đi xe cách người kia vài bước chân.', 'bánh xe của anh ấy ở xa đường kẻ trắng hơn.', 'người đi xe đạp ở gần đường kẻ hơn.']
# =====================================

# %% [markdown]
# ## Check the score of the translations

# %%
import os
import json
datasets_dir = '../../../datasets/VQA-X'
evaluation_dir = os.path.join(datasets_dir, 'evaluation')
train_file_path = os.path.join(evaluation_dir, 'train_gpt_evaluation.json')

# Hàm để sửa các object bị lỗi
def fix_explanation_scores(obj):
    explanation = obj['explanation']
    explanation_scores = obj["explanation_scores"]

    # Đảm bảo rằng explanation_scores có số lượng phần tử tương ứng với các phần tử trong explanation
    if len(explanation) == 1:
        if len(explanation_scores) < 4 and obj["explanation_scores"][0] != []:
            obj["explanation_scores"] = [obj["explanation_scores"][0]]
        elif len(explanation_scores) == 4:
            # print(obj["id_image"], obj["explanation_scores"])
            obj["explanation_scores"] = [[explan[0] for explan in obj["explanation_scores"]]]
    return obj

# Gọi hàm để sửa file
with open(train_file_path, 'r', encoding='utf-8') as f:
    train_data = json.load(f)
    for obj in train_data:
        fix_explanation_scores(obj)
        
with open(train_file_path, 'w', encoding='utf-8') as f:
    json.dump(train_data, f, ensure_ascii=False, indent=2)
    
print("Fixed explanation scores in train data")
# Out:
# Fixed explanation scores in train data

# %%
import os
import json

# Đường dẫn tới thư mục datasets và evaluation
datasets_dir = '../../../datasets/VQA-X'
evaluation_dir = os.path.join(datasets_dir, 'evaluation')
llm_models = ['llama', 'qwen', 'phi','gemma','gpt']
evaluation_files = ['val', 'test', 'train']

# Hàm kiểm tra các trường score
def check_scores_length(data):
    errors = []
    for entry in data:
        if len(entry['question_scores']) != len(entry['question']):
            errors.append(f"Mismatch in question_scores: {entry['id_image']}")
        if len(entry['answer_scores']) != len(entry['answer']):
            errors.append(f"Mismatch in answer_scores: {entry['id_image']}")
        for i, expl_scores in enumerate(entry['explanation_scores']):
            try:
                if len(expl_scores) != len(entry['explanation'][i]):
                    errors.append(f"Mismatch in explanation_scores[{i}]: {entry['id_image']}")
            except:
                errors.append(f"Error in explanation_scores[{i}]: {entry['id_image']}")

    return errors

# Kiểm tra các file JSON của từng LLM
for model in llm_models:
    for eval_file in evaluation_files:
        file_path = os.path.join(evaluation_dir, f"{eval_file}_{model}_evaluation.json")
        if os.path.exists(file_path):
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                errors = check_scores_length(data)
                if errors:
                    print(f"Errors in {file_path}:")
                    for error in errors:
                        print(f"  - {error}")
                else:
                    print(f"No errors found in {eval_file}_{model}_evaluation.json")
        else:
            print(f"File {file_path} does not exist.")
# Out:
# No errors found in val_llama_evaluation.json
# No errors found in test_llama_evaluation.json
# No errors found in train_llama_evaluation.json
# No errors found in val_qwen_evaluation.json
# No errors found in test_qwen_evaluation.json
# No errors found in train_qwen_evaluation.json
# No errors found in val_phi_evaluation.json
# No errors found in test_phi_evaluation.json
# No errors found in train_phi_evaluation.json
# No errors found in val_gemma_evaluation.json
# No errors found in test_gemma_evaluation.json
# No errors found in train_gemma_evaluation.json
# No errors found in val_gpt_evaluation.json
# No errors found in test_gpt_evaluation.json
# No errors found in train_gpt_evaluation.json

# %% [markdown]
# ## Merge the scores

# %%
import json
import os

datasets_dir = '../../../datasets/VQA-X'
evaluation_dir = os.path.join(datasets_dir, 'evaluation')
llm_models = ['llama', 'qwen', 'phi', 'gemma', 'gpt']
evaluation_files = ['train', 'val', 'test']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

def merge_evaluation_data(**json_files):
    merged_data = {}
    
    for model_name, file_path in json_files.items():
        data = load_json(file_path)
        
        for entry in data:
            id_image = entry["id_image"]
            if id_image not in merged_data:
                merged_data[id_image] = {
                    "id_image": id_image,
                    "question": entry["question"],
                    "question_scores": {},
                    "answer": entry["answer"],
                    "answer_scores": {},
                    "explanation": entry["explanation"],
                    "explanation_scores": {model_name: entry["explanation_scores"]}
                }
            
            # Add scores with the model name as the key
            merged_data[id_image]["question_scores"][model_name] = entry["question_scores"]
            merged_data[id_image]["answer_scores"][model_name] = entry["answer_scores"]
        
            merged_data[id_image]["explanation_scores"][model_name] = entry["explanation_scores"]

    return list(merged_data.values())

# Process each dataset (train, val, test)
for evaluation_file in evaluation_files:
    # Define paths to the JSON files for each model and the current evaluation file
    json_files = {
        model: os.path.join(evaluation_dir, f"{evaluation_file}_{model}_evaluation.json")
        for model in llm_models
    }
    
    # Merge the data for the current evaluation file
    merged_data = merge_evaluation_data(**json_files)
    
    # Save the merged data
    output_path = os.path.join(evaluation_dir, f'vqaX_{evaluation_file}_evaluation.json')
    with open(output_path, 'w', encoding='utf-8') as outfile:
        json.dump(merged_data, outfile, indent=2, ensure_ascii=False)
    
    print(f"Merged data for {evaluation_file} saved to {output_path}")
# Out:
# Merged data for train saved to ../../../datasets/VQA-X/evaluation/vqaX_train_evaluation.json
# Merged data for val saved to ../../../datasets/VQA-X/evaluation/vqaX_val_evaluation.json
# Merged data for test saved to ../../../datasets/VQA-X/evaluation/vqaX_test_evaluation.json

# %% [markdown]
# ## Test gpt

# %%
import openai
import json
from dotenv import load_dotenv
import os
load_dotenv()
# Đặt API key của bạn
openai.api_key = os.getenv("OPENAI_API_KEY")
prompt = """
You will be given an English question, answer, and explanations for context. Then, you will evaluate Vietnamese translations of the question, answer, and explanation(s). Evaluate each translation based on accuracy, fluency, and cultural appropriateness, considering the full context provided. Assign a score between 0 and 100 for each translation.

**Return the scores in the following JSON format and no additional text or explanations:**

{{
    "question_scores": [score_for_translation_1, score_for_translation_2, ...],
    "answer_scores": [score_for_translation_1, score_for_translation_2, ...],
    "explanation_scores": [
        [score for translations of explanation 1],
        [score for translations of explanation 2], (if multiple explanations are provided)
        ...
    ] (length of this list should match the number of explanations provided)
}}

Now, please evaluate the following:
"""
content_user = """
English Question: How many legs does a cat have?
Translation 1: Mèo có bao nhiêu chân?
Translation 2: Mèo có mấy chân?
Translation 3: Mèo có mấy cái chân?

English Answer: A cat has four legs.
Translation 1: Mèo có bốn chân.
Translation 2: Mèo có 4 chân.
Translation 3: Mèo có bốn cái chân.

Explanation 1: Cats are quadrupedal animals.
Translation 1: Mèo là động vật có bốn chân.
Translation 2: Mèo là loài động vật có bốn chân.
Translation 3: Mèo là loài động vật có bốn cái chân.
"""


messages = [
    {"role": "system", "content": prompt},
    {"role": "user", "content": content_user}
]

# Gọi API
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    max_tokens=100,
    temperature=0.1,
    response_format={"type": "json_object"}
)

# %%
print(response.choices[0].message.content)
json_object = json.loads(response.choices[0].message.content)
json_object['explain_score']
# Out:
# {
#     "question_score": [90, 95, 85],
#     "answer_score": [95, 95, 85],
#     "explain_score": [
#         [90, 95, 85]
#     ]
# }
# [[90, 95, 85]]

# %%
import json
import pandas as pd

# Đường dẫn đến các file dữ liệu
datasets_dir = '../../../datasets/VQA-X'
dataset_files = ['vqaX_train_translated.json', 'vqaX_val_translated.json', 'vqaX_test_translated.json']

# Hàm để lấy tất cả các câu trả lời từ một file
def get_answers_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    answers = []
    for key, item in data.items():
        answers.append((key, item['answer_vi_gemini']))
    
    return answers

# Lấy tất cả các câu trả lời từ tất cả các file
all_answers = []
for file in dataset_files:
    file_path = f"{datasets_dir}/{file}"
    all_answers.extend(get_answers_from_file(file_path))

sorted_answers = sorted(all_answers, key=lambda x: x[1])
df = pd.DataFrame(sorted_answers, columns=['id', 'answer_vi_gemini'])
output_file = 'vqax_answer_gemini.csv'
df.to_csv(output_file, index=False, encoding='utf-8-sig')

print(f"Đã lưu {len(sorted_answers)} câu trả lời duy nhất vào file {output_file}")
# Out:
# Đã lưu 32886 câu trả lời duy nhất vào file vqax_answer_gemini.csv

# %% [markdown]
# ## Calculate tokens

# %%
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import tiktoken
from collections import Counter
enc = tiktoken.encoding_for_model('gpt-4o-mini')
def count_tokens(text):
    return len(enc.encode(text))

def get_most_common_answers(answers, n=10):
    counter = Counter(answers)
    
    return counter.most_common(n)
def count_data_tokens(data: dict):
    total_tokens = 0
    quest_tokens = 0
    ans_tokens = 0
    expl_tokens = 0
    for key, value in data.items():
        # Count tokens in each question
        quest_tokens += count_tokens(value['question'])
        
        
        # just count most common answer
        answers = [ans['answer'] for ans in value['answers']]
        most_common_answer = get_most_common_answers(answers, 1)[0][0]
        ans_tokens += count_tokens(most_common_answer)
        
        # count tokens in each explanation
        if 'explanation' in value:
            for explanation in value['explanation']:
                expl_tokens += count_tokens(explanation)
    
    total_tokens = quest_tokens + ans_tokens + expl_tokens
    
    return {
        "total_tokens": total_tokens,
        "question_tokens": quest_tokens,
        "answer_tokens": ans_tokens,
        "explanation_tokens": expl_tokens 
    }

# example usage
tokens = count_data_tokens(train_data)
print(f"Total: {tokens['total_tokens']}")
print(f"Question: {tokens['question_tokens']}")
print(f"Answer: {tokens['answer_tokens']}")
print(f"Explanation: {tokens['explanation_tokens']}")


tokens = count_data_tokens(val_data)
print(f"Total: {tokens['total_tokens']}")
print(f"Question: {tokens['question_tokens']}")
print(f"Answer: {tokens['answer_tokens']}")
print(f"Explanation: {tokens['explanation_tokens']}")
tokens = count_data_tokens(test_data)
print(f"Total: {tokens['total_tokens']}")
print(f"Question: {tokens['question_tokens']}")
print(f"Answer: {tokens['answer_tokens']}")
print(f"Explanation: {tokens['explanation_tokens']}")
# Out:
# Total: 514854
# Question: 193878
# Answer: 40479
# Explanation: 280497
# Total: 52326
# Question: 9648
# Answer: 2195
# Explanation: 40483
# Total: 70226
# Question: 12564
# Answer: 2908
# Explanation: 54754
