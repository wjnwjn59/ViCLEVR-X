# %%
import os
import json

# Set paths
datasets_dir = '../../../datasets'
vqax_dir = os.path.join(datasets_dir, 'VQA-X')
train_dir = os.path.join(vqax_dir, 'vqaX_train.json')
test_dir = os.path.join(vqax_dir, 'vqaX_test.json')
val_dir = os.path.join(vqax_dir, 'vqaX_val.json')
with open(train_dir) as f:
    train_data = json.load(f)
with open(test_dir) as f:
    test_data = json.load(f)
with open(val_dir) as f:
    val_data = json.load(f)

# %%
print(json.dumps(test_data['262284001'],indent=2))
# Out:
# {
#   "question": "What is this?",
#   "answers": [
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 1
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 2
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 3
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 4
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "maybe",
#       "answer_id": 5
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 6
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 7
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 8
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 9
#     },
#     {
#       "answer": "shower",
#       "answer_confidence": "yes",
#       "answer_id": 10
#     }
#   ],
#   "image_id": "262284",
#   "image_name": "COCO_val2014_000000262284.jpg",
#   "explanation": [
#     "it has a shower head hanging inside of it",
#     "there is a shower head",
#     "there is a faucet and a bathtub"
#   ]
# }

# %% [markdown]
# ## Combine translations into one object

# %% [markdown]
# ## Verifying the translations

# %%
import json
import os

# Đường dẫn đến thư mục chứa các file dữ liệu
datasets_dir = '../../../datasets/VQA-X'

# Danh sách các tập dữ liệu
datasets = ['train', 'val', 'test']

# Danh sách các nguồn dịch
translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

def check_data_integrity(datasets_dir, datasets, translation_sources):
    for dataset in datasets:
        print(f"Checking {dataset} dataset...")
        
        # Load merged data
        merged_file = f'{datasets_dir}/vqaX_{dataset}_translated.json'
        merged_data = load_json(merged_file)
        
        error_items = {}
        
        for key, item in merged_data.items():
            item_errors = []
            
            # Check original fields
            if not item['question'] or not item['answers'] or not item['explanation']:
                item_errors.append("Missing original fields")
            
            # Check translated fields
            for source in translation_sources:
                question_key = f'question_vi_{source}'
                answer_key = f'answer_vi_{source}'
                explanation_key = f'explanation_vi_{source}'
                
                if question_key not in item or not item[question_key]:
                    item_errors.append(f"Missing or empty {question_key}")
                
                if answer_key not in item or not item[answer_key]:
                    item_errors.append(f"Missing or empty {answer_key}")
                
                if explanation_key not in item:
                    item_errors.append(f"Missing {explanation_key}")
                elif not item[explanation_key]:
                    item_errors.append(f"Empty {explanation_key}")
                elif len(item[explanation_key]) != len(item['explanation']):
                    item_errors.append(f"Mismatch in number of explanations for {explanation_key}")
                elif any(not exp for exp in item[explanation_key]):
                    item_errors.append(f"Empty explanation in {explanation_key}")
            
            if item_errors:
                error_items[key] = item_errors
        
        # Save error items
        error_file = f'{dataset}_errors.json'
        with open(error_file, 'w', encoding='utf-8') as f:
            json.dump(error_items, f, ensure_ascii=False, indent=2)
        
        print(f"Total items: {len(merged_data)}")
        print(f"Items with errors: {len(error_items)}")
        print("\n")

# Run the integrity check
check_data_integrity(datasets_dir, datasets, translation_sources)
# Out:
# Checking train dataset...
# Total items: 29459
# Items with errors: 0
#
#
# Checking val dataset...
# Total items: 1459
# Items with errors: 0
#
#
# Checking test dataset...
# Total items: 1968
# Items with errors: 0

# %%
import json
import os

# Đường dẫn đến thư mục chứa các file dữ liệu
datasets_dir = '../../../datasets/VQA-X'

# Danh sách các tập dữ liệu
datasets = ['train', 'val', 'test']

# Danh sách các nguồn dịch
translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return json.load(f)

def merge_translations(datasets_dir, datasets, translation_sources):
    for dataset in datasets:
        print(f"Processing {dataset} dataset...")
        
        # Load original data
        original_file = f'{datasets_dir}/vqaX_{dataset}.json'
        original_data = load_json(original_file)
        
        # Load translations
        translations = {}
        for source in translation_sources:
            translation_file = f'{datasets_dir}/vqaX_{dataset}_{source}.json'
            if os.path.exists(translation_file):
                translations[source] = load_json(translation_file)
            else:
                print(f"Warning: {translation_file} not found. Skipping this translation source.")
        
        # Merge translations
        merged_data = {}
        for key, item in original_data.items():
            merged_item = item.copy()
            for source in translation_sources:
                if source in translations and key in translations[source]:
                    translated_item = translations[source][key]
                    merged_item[f'question_vi_{source}'] = translated_item.get(f'question_vi_{source}')
                    merged_item[f'answer_vi_{source}'] = translated_item.get(f'answer_vi_{source}')
                    merged_item[f'explanation_vi_{source}'] = translated_item.get(f'explanation_vi_{source}')
            merged_data[key] = merged_item
        
        # Save merged data
        output_file = f'{datasets_dir}/vqaX_{dataset}_translated.json'
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(merged_data, f, ensure_ascii=False, indent=2)
        print(f"Merged data saved to {output_file}")
        
        # Print some statistics
        print(f"Total items in original data: {len(original_data)}")
        print(f"Total items in merged data: {len(merged_data)}")
        for source in translation_sources:
            if source in translations:
                print(f"Items with {source} translation: {sum(1 for item in merged_data.values() if f'question_vi_{source}' in item)}")
        print("\n")

# Run the merging process
merge_translations(datasets_dir, datasets, translation_sources)
# Out:
# Processing train dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_train_translated.json
# Total items in original data: 29459
# Total items in merged data: 29459
# Items with vinai translation: 29459
# Items with gemini translation: 29459
# Items with ggtrans translation: 29459
# Items with gpt translation: 29459
#
#
# Processing val dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_val_translated.json
# Total items in original data: 1459
# Total items in merged data: 1459
# Items with vinai translation: 1459
# Items with gemini translation: 1459
# Items with ggtrans translation: 1459
# Items with gpt translation: 1459
#
#
# Processing test dataset...
# Merged data saved to ../../../datasets/VQA-X/vqaX_test_translated.json
# Total items in original data: 1968
# Total items in merged data: 1968
# Items with vinai translation: 1968
# Items with gemini translation: 1968
# Items with ggtrans translation: 1968
# Items with gpt translation: 1968

# %% [markdown]
# ## Visualize argmax vs sampling

# %%
import os
import json
import pandas as pd
import random
random.seed(0)
from collections import Counter

def get_most_common_answer(answers):
    return Counter(answer['answer'] for answer in answers).most_common(1)[0][0]


def load_data(dataset_type, datasets_dir='../../../datasets/VQA-X/'):
    pp_dir = os.path.join(datasets_dir, 'final_data/post_processing')
    vote_dir = os.path.join(datasets_dir, 'final_data/argmax')

    with open(os.path.join(datasets_dir, f'vqaX_{dataset_type}_translated.json')) as f:
        data = json.load(f)

    argmax_data = pd.read_csv(os.path.join(vote_dir, f'{dataset_type}_argmax.csv'))
    sampling_data = pd.read_csv(os.path.join(pp_dir, f'vqaX_{dataset_type}_translated.csv'))

    return data, argmax_data, sampling_data

def print_sample_info(data, argmax_data, sampling_data, num_samples=100):
    translation_sources = ['vinai', 'gemini', 'ggtrans', 'gpt']

    indices = random.sample(list(data.keys()), num_samples)

    for idx in indices:
        print(f"ID: {idx}")
        print(f"Question: {data[idx]['question']}")
        print(f"Answers: {get_most_common_answer(data[idx]['answers'])}")
        for i, explanation in enumerate(data[idx]['explanation']):
            print(f"Explanation {i}: {explanation}")
            
            # Lấy dữ liệu từ argmax
            argmax_row = argmax_data[argmax_data['question_id'] == int(idx)]
            if not argmax_row.empty:
                print(f"Argmax: {argmax_row['explanation'].values[0].split('###')[i]}")
            
            # Lấy dữ liệu từ sampling
            sampling_row = sampling_data[sampling_data['question_id'] == int(idx)]
            if not sampling_row.empty:
                print(f"Sampling: {sampling_row['explanation'].values[0].split('###')[i]}")
            
            # In các translation từ các nguồn khác nhau
            for source in translation_sources:
                print(f"  {source}: {data[idx][f'explanation_vi_{source}'][i]}")
            print()
        print("="*100)

def process_dataset(dataset_type, num_samples=100):
    data, argmax_data, sampling_data = load_data(dataset_type)
    print_sample_info(data, argmax_data, sampling_data, num_samples)

process_dataset('train', num_samples=100)
# Out:
# ID: 122964003
# Question: What kind of room is this?
# Answers: kitchen
# Explanation 0: you can use the nice sink to wash vegetables
# Argmax: bạn có thể sử dụng bồn rửa đẹp để rửa rau
# Sampling: bạn có thể sử dụng bồn rửa đẹp để rửa rau củ
#   vinai: bạn có thể sử dụng bồn rửa đẹp để rửa rau
#   gemini: bạn có thể sử dụng bồn rửa tiện lợi để rửa rau
#   ggtrans: bạn có thể sử dụng bồn rửa đẹp để rửa rau
#   gpt: bạn có thể sử dụng bồn rửa đẹp để rửa rau củ
#
# ====================================================================================================
# ID: 184999000
# Question: Is this mall crowded?
# Answers: no
# Explanation 0: there are no people walking around
# Argmax: không có người đi lại xung quanh
# Sampling: không có người đi bộ xung quanh
#   vinai: không có người đi bộ xung quanh
#   gemini: không có ai đi bộ xung quanh
#   ggtrans: không có người đi lại xung quanh
#   gpt: không có ai đi lại
#
# ====================================================================================================
# ID: 192954004
# Question: What room is this?
# Answers: living room
# Explanation 0: the fireplace is warming the couch and chair
# Argmax: lò sưởi đang sưởi ấm ghế sofa và ghế
# Sampling: lò sưởi đang sưởi ấm ghế sofa và ghế
#   vinai: lò sưởi đang sưởi ấm ghế và ghế
#   gemini: lò sưởi đang sưởi ấm ghế sofa và ghế
#   ggtrans: lò sưởi đang sưởi ấm chiếc ghế dài và ghế
#   gpt: lò sưởi đang làm ấm ghế sofa và ghế
#
# Explanation 1: it has living room furniture and a fireplace in it
# Argmax: nó có đồ nội thất phòng khách và một lò sưởi trong đó
# Sampling: nó có đồ nội thất phòng khách và lò sưởi bên trong
#   vinai: nó có đồ nội thất phòng khách và lò sưởi trong đó
#   gemini: nó có đồ nội thất phòng khách và lò sưởi bên trong
#   ggtrans: nó có đồ nội thất phòng khách và một lò sưởi trong đó
#   gpt: nó có nội thất phòng khách và một lò sưởi trong đó
#
# ====================================================================================================
# ID: 522922008
# Question: What room is this?
# Answers: bedroom
# Explanation 0: there is a bed in the room
# Argmax: có một chiếc giường trong phòng
# Sampling: trong phòng có một cái giường
#   vinai: Có một cái giường trong phòng.
#   gemini: có một chiếc giường trong phòng
#   ggtrans: có một cái giường trong phòng
#   gpt: trong phòng có một cái giường
#
# ====================================================================================================
# ID: 97982002
# Question: Is this a freight train?
# Answers: yes
# Explanation 0: the train cars suggest there are no people present
# Argmax: những toa tàu cho thấy không có người ở đó
# Sampling: những toa tàu cho thấy không có người ở đó
#   vinai: Các toa tàu cho thấy không có người có mặt
#   gemini: các toa tàu cho thấy không có người hiện diện
#   ggtrans: những toa tàu cho thấy không có người ở đó
#   gpt: các toa tàu gợi ý rằng không có người có mặt
#
# ====================================================================================================
# ID: 136970001
# Question: Is it raining?
# Answers: no
# Explanation 0: the grass is still dry
# Argmax: cỏ vẫn khô
# Sampling: cỏ vẫn khô
#   vinai: cỏ vẫn còn khô
#   gemini: cỏ vẫn khô
#   ggtrans: cỏ vẫn khô
#   gpt: cỏ vẫn khô
#
# ====================================================================================================
# ID: 560615002
# Question: Is the crowd looking at the police?
# Answers: no
# Explanation 0: they have their back to have them
# Argmax: họ quay lưng lại với họ
# Sampling: họ quay lưng lại với họ
#   vinai: Họ có lưng để có chúng.
#   gemini: họ quay lưng lại với họ
#   ggtrans: họ có lưng để có chúng
#   gpt: họ quay lưng lại với họ
#
# ====================================================================================================
# ID: 188151002
# Question: What sport are they participating in?
# Answers: skiing
# Explanation 0: the group is posing on their skis at the top of a mountain slope
# Argmax: nhóm người đang tạo dáng trên ván trượt của họ ở đỉnh một sườn núi
# Sampling: Cả nhóm đang tạo dáng trên ván trượt của họ trên đỉnh một sườn núi.
#   vinai: Cả nhóm đang tạo dáng trên ván trượt của họ trên đỉnh một sườn núi.
#   gemini: nhóm người đang tạo dáng trên ván trượt của họ ở đỉnh một sườn núi
#   ggtrans: cả nhóm đang tạo dáng trên ván trượt trên đỉnh dốc núi
#   gpt: nhóm đang tạo dáng trên ván trượt tại đỉnh một sườn núi
#
# Explanation 1: they are wearing ski clothes with skis on their feet on the snowy hill
# Argmax: họ đang mặc quần áo trượt tuyết với ván trượt trên chân trên ngọn đồi tuyết
# Sampling: họ đang mặc quần áo trượt tuyết với ván trượt trên chân của họ trên ngọn đồi tuyết
#   vinai: họ đang mặc quần áo trượt tuyết với ván trượt trên chân của họ trên ngọn đồi tuyết
#   gemini: họ mặc quần áo trượt tuyết với ván trượt trên chân trên ngọn đồi tuyết
#   ggtrans: họ đang mặc quần áo trượt tuyết với ván trượt trên chân trên ngọn đồi tuyết
#   gpt: họ đang mặc trang phục trượt tuyết với ván trượt trên chân trên đồi tuyết
#
# ====================================================================================================
# ID: 461535006
# Question: What are the people holding?
# Answers: ski poles
# Explanation 0: they are skiing along a trail
# Argmax: họ đang trượt tuyết dọc theo một con đường mòn
# Sampling: họ đang trượt tuyết dọc theo một con đường mòn
#   vinai: họ đang trượt tuyết dọc theo một con đường mòn
#   gemini: họ đang trượt tuyết dọc theo một con đường mòn
#   ggtrans: họ đang trượt tuyết dọc theo một con đường mòn
#   gpt: họ đang trượt tuyết trên một con đường mòn
#
# ====================================================================================================
# ID: 449939000
# Question: Is this skateboarder a man?
# Answers: no
# Explanation 0: she has boobs
# Argmax: cô ấy có ngực
# Sampling: cô ấy có ngực
#   vinai: cô ấy có ngực
#   gemini: cô ấy có ngực
#   ggtrans: cô ấy có bộ ngực
#   gpt: cô ấy có ngực
#
# ====================================================================================================
# ID: 506664004
# Question: Is this a city street?
# Answers: yes
# Explanation 0: there are vehicles traveling in a row on an asphalt surface with traffic lights
# Argmax: có những chiếc xe chạy thành hàng trên mặt đường nhựa có đèn giao thông
# Sampling: có những chiếc xe chạy thành hàng trên mặt đường nhựa có đèn giao thông
#   vinai: có những phương tiện di chuyển liên tiếp trên bề mặt nhựa đường với đèn giao thông
#   gemini: có những phương tiện giao thông đang di chuyển nối đuôi nhau trên một mặt đường nhựa với đèn giao thông
#   ggtrans: có những chiếc xe chạy thành hàng trên mặt đường nhựa có đèn giao thông
#   gpt: Có các phương tiện di chuyển theo hàng trên bề mặt nhựa đường với đèn giao thông.
#
# ====================================================================================================
# ID: 513708000
# Question: What is the flooring made of?
# Answers: wood
# Explanation 0: it is a hard flooring with planks and without grout
# Argmax: đó là một sàn cứng với tấm ván và không có vữa
# Sampling: nó là một sàn cứng với ván và không có vữa
#   vinai: nó là một sàn cứng với ván và không có vữa
#   gemini: đó là một sàn cứng với tấm ván và không có vữa
#   ggtrans: nó là một sàn cứng với ván và không có vữa
#   gpt: đó là một sàn cứng với các tấm và không có mạch.
#
# ====================================================================================================
# ID: 435848002
# Question: Is the bathroom clean?
# Answers: yes
# Explanation 0: it is not cluttered
# Argmax: nó không lộn xộn
# Sampling: nó không lộn xộn
#   vinai: nó không lộn xộn
#   gemini: nó không lộn xộn
#   ggtrans: nó không lộn xộn
#   gpt: nó không lộn xộn
#
# ====================================================================================================
# ID: 460254006
# Question: What sport is being played?
# Answers: tennis
# Explanation 0: the ball is going over the tennis net
# Argmax: quả bóng đang bay qua lưới tennis
# Sampling: quả bóng đang đi qua lưới tennis
#   vinai: quả bóng đang đi qua lưới tennis
#   gemini: quả bóng đang đi qua lưới quần vợt
#   ggtrans: quả bóng đang bay qua lưới tennis
#   gpt: quả bóng đang bay qua lưới tennis
#
# ====================================================================================================
# ID: 574360001
# Question: Is this a mountainous area?
# Answers: yes
# Explanation 0: there are mountains in the background
# Argmax: có những ngọn núi ở phía sau
# Sampling: có những ngọn núi ở hậu cảnh
#   vinai: có những ngọn núi ở phía sau
#   gemini: có những ngọn núi ở hậu cảnh
#   ggtrans: có những ngọn núi ở phía sau
#   gpt: có những ngọn núi ở phía sau
#
# ====================================================================================================
# ID: 475656006
# Question: Is this a two way street?
# Answers: yes
# Explanation 0: it is broad enough for passing and has no one-way signs marked
# Argmax: nó đủ rộng để đi qua và không có biển báo một chiều nào được đánh dấu
# Sampling: Nó đủ rộng để vượt qua và không có dấu hiệu một chiều nào được đánh dấu.
#   vinai: nó đủ rộng để đi qua và không có biển báo một chiều được đánh dấu
#   gemini: nó đủ rộng để vượt qua và không có biển báo đường một chiều được đánh dấu
#   ggtrans: nó đủ rộng để đi qua và không có biển báo một chiều nào được đánh dấu
#   gpt: Nó đủ rộng để vượt qua và không có dấu hiệu một chiều nào được đánh dấu.
#
# ====================================================================================================
# ID: 392030000
# Question: What room is this?
# Answers: kitchen
# Explanation 0: it has a stove and lot of tables
# Argmax: nó có bếp lò và nhiều bàn
# Sampling: nó có bếp và nhiều bàn
#   vinai: nó có một bếp lò và rất nhiều bàn
#   gemini: nó có bếp lò và nhiều bàn
#   ggtrans: nó có một cái bếp và rất nhiều bàn
#   gpt: nó có bếp và nhiều bàn
#
# ====================================================================================================
# ID: 161740002
# Question: Is the animal inside the oven alive?
# Answers: yes
# Explanation 0: he is standing with his eyes open
# Argmax: anh ấy đang đứng với đôi mắt mở to
# Sampling: Nó đang đứng với đôi mắt mở.
#   vinai: ông đang đứng với đôi mắt mở
#   gemini: nó đang đứng với đôi mắt mở
#   ggtrans: anh ấy đang đứng với đôi mắt mở to
#   gpt: Nó đang đứng với đôi mắt mở.
#
# ====================================================================================================
# ID: 70863002
# Question: Is the man happy?
# Answers: yes
# Explanation 0: he is smiling and cheerfully playing the guitar
# Argmax: anh ấy đang mỉm cười và vui vẻ chơi guitar
# Sampling: anh ấy đang cười và vui vẻ chơi guitar
#   vinai: Ông đang mỉm cười và vui vẻ chơi guitar.
#   gemini: anh ấy đang cười và vui vẻ chơi đàn ghi-ta
#   ggtrans: anh ấy đang mỉm cười và vui vẻ chơi guitar
#   gpt: anh ấy đang cười và vui vẻ chơi guitar
#
# ====================================================================================================
# ID: 281578000
# Question: Is this a busy office?
# Answers: no
# Explanation 0: there isn't a single human being in it
# Argmax: không có một con người nào trong đó
# Sampling: không có một người nào trong đó
#   vinai: không có một con người nào trong đó.
#   gemini: không có một người nào ở trong đó
#   ggtrans: không có một con người nào trong đó
#   gpt: không có một người nào trong đó
#
# ====================================================================================================
# ID: 334285002
# Question: Is this a cafe?
# Answers: yes
# Explanation 0: there are many tables scattered about the area
# Argmax: có nhiều bàn được đặt rải rác xung quanh khu vực này
# Sampling: có nhiều bàn nằm rải rác trong khu vực
#   vinai: có rất nhiều bảng nằm rải rác trong khu vực
#   gemini: có nhiều bàn được đặt rải rác xung quanh khu vực này
#   ggtrans: có nhiều bàn nằm rải rác trong khu vực
#   gpt: Có nhiều bàn được đặt rải rác trong khu vực.
#
# ====================================================================================================
# ID: 412760004
# Question: Can the horses cross the water?
# Answers: yes
# Explanation 0: the water is very shallow
# Argmax: nước rất nông
# Sampling: nước rất nông
#   vinai: Nước rất cạn.
#   gemini: nước rất nông
#   ggtrans: nước rất nông
#   gpt: nước rất nông
#
# ====================================================================================================
# ID: 502058007
# Question: What kind of animal is this?
# Answers: sheep
# Explanation 0: the animals are covered in wool
# Argmax: các loài động vật được bao phủ bởi lông cừu
# Sampling: những con vật được bao phủ trong len
#   vinai: những con vật được bao phủ trong len
#   gemini: những con vật được bao phủ bởi len
#   ggtrans: các loài động vật được bao phủ bởi len
#   gpt: các loài động vật được bao phủ bởi lông cừu
#
# ====================================================================================================
# ID: 445621001
# Question: What is the guy doing?
# Answers: skateboarding
# Explanation 0: he is at the skate park
# Argmax: anh ấy đang ở công viên trượt ván
# Sampling: anh ấy đang ở công viên trượt ván
#   vinai: Anh ta đang ở công viên trượt ván.
#   gemini: anh ấy đang ở công viên trượt ván
#   ggtrans: anh ấy đang ở công viên trượt băng
#   gpt: Anh ấy ở công viên trượt ván.
#
# ====================================================================================================
# ID: 349943003
# Question: Is anyone in this photo sitting?
# Answers: no
# Explanation 0: everyone is standing on there feet
# Argmax: tất cả mọi người đang đứng trên đôi chân đó
# Sampling: mọi người đều đứng trên chân
#   vinai: tất cả mọi người đang đứng trên đôi chân đó
#   gemini: mọi người đều đứng trên chân
#   ggtrans: mọi người đang đứng trên đôi chân đó
#   gpt: Tất cả mọi người đều đứng trên đôi chân của họ.
#
# ====================================================================================================
# ID: 73690052
# Question: Is the photo colored?
# Answers: yes
# Explanation 0: you can see the green and orange shirts of the man and woman
# Argmax: bạn có thể thấy những chiếc áo màu xanh lá cây và màu cam của người đàn ông và người phụ nữ
# Sampling: bạn có thể thấy những chiếc áo màu xanh lá cây và màu cam của người đàn ông và người phụ nữ
#   vinai: bạn có thể thấy áo sơ mi màu xanh lá cây và màu cam của đàn ông và phụ nữ
#   gemini: bạn có thể thấy áo màu xanh lá cây và cam của người đàn ông và người phụ nữ
#   ggtrans: bạn có thể thấy những chiếc áo màu xanh lá cây và màu cam của người đàn ông và người phụ nữ
#   gpt: Bạn có thể thấy áo xanh lá cây và áo cam của người đàn ông và người phụ nữ.
#
# ====================================================================================================
# ID: 49551015
# Question: Sunny or overcast?
# Answers: overcast
# Explanation 0: the sky is gloomy and cloudy
# Argmax: bầu trời u ám và nhiều mây
# Sampling: bầu trời u ám và nhiều mây
#   vinai: bầu trời ảm đạm và nhiều mây
#   gemini: bầu trời u ám và nhiều mây
#   ggtrans: bầu trời u ám và nhiều mây
#   gpt: bầu trời u ám và có mây
#
# ====================================================================================================
# ID: 468100000
# Question: Is this a gravel or a dirt road?
# Answers: gravel
# Explanation 0: it is a paved road made of gravel
# Argmax: đó là một con đường trải sỏi
# Sampling: đó là một con đường trải nhựa làm từ sỏi
#   vinai: Đó là một con đường lát đá sỏi.
#   gemini: đó là một con đường được lát bằng sỏi
#   ggtrans: đó là một con đường trải sỏi
#   gpt: đó là một con đường trải nhựa làm từ sỏi
#
# ====================================================================================================
# ID: 363038002
# Question: Does the sink have water in it?
# Answers: no
# Explanation 0: the cat is in it and cats hate water
# Argmax: con mèo đang ở trong đó và mèo ghét nước
# Sampling: con mèo ở trong đó và mèo ghét nước
#   vinai: con mèo ở trong đó và con mèo ghét nước
#   gemini: con mèo đang ở trong đó và mèo ghét nước
#   ggtrans: con mèo ở trong đó và mèo ghét nước
#   gpt: con mèo đang ở trong đó và mèo thì ghét nước
#
# ====================================================================================================
# ID: 379678001
# Question: Does the signal indicate to proceed forward?
# Answers: yes
# Explanation 0: it's green the direction i'm headed
# Argmax: Hướng tôi đang đi có màu xanh lá cây.
# Sampling: hướng tôi đang đi là màu xanh lá cây
#   vinai: Hướng tôi đang đi có màu xanh lá cây.
#   gemini: nó màu xanh lá cây theo hướng tôi đang đi
#   ggtrans: hướng tôi đang đi là màu xanh lá cây
#   gpt: nó màu xanh theo hướng tôi đang đi
#
# ====================================================================================================
# ID: 216391005
# Question: Is the shorter guy smoking a cigarette?
# Answers: no
# Explanation 0: he isn't holding one or smoking one
# Argmax: anh ấy không cầm một điếu hay hút thuốc
# Sampling: anh ấy không cầm một điếu hay hút thuốc
#   vinai: Hắn không cầm súng hay hút thuốc.
#   gemini: anh ấy không cầm hoặc hút thuốc lá
#   ggtrans: anh ấy không cầm một điếu hay hút thuốc
#   gpt: anh ấy không cầm một điếu nào cũng như không hút một điếu nào
#
# ====================================================================================================
# ID: 544875003
# Question: Does the area look like a comfortable place to take a shit?
# Answers: no
# Explanation 0: it is a hard floor and gross looking
# Argmax: Nó là một sàn nhà cứng và nhìn gớm ghiếc.
# Sampling: nó là một sàn cứng và trông thô thiển
#   vinai: Nó là một sàn nhà cứng và nhìn gớm ghiếc.
#   gemini: nó là sàn cứng và trông thật ghê tởm
#   ggtrans: nó là một sàn cứng và trông thô thiển
#   gpt: đó là một sàn cứng và trông bẩn thỉu
#
# ====================================================================================================
# ID: 43511000
# Question: Does this animal belong here?
# Answers: no
# Explanation 0: there are dangerous trains nearby
# Argmax: có những chuyến tàu nguy hiểm ở gần đó
# Sampling: Có những đoàn tàu nguy hiểm gần đó.
#   vinai: Có những đoàn tàu nguy hiểm gần đó.
#   gemini: có những đoàn tàu nguy hiểm gần đó
#   ggtrans: có những chuyến tàu nguy hiểm ở gần đó
#   gpt: Có những con tàu nguy hiểm gần đây
#
# ====================================================================================================
# ID: 275885000
# Question: Is the dog waiting for a treat?
# Answers: yes
# Explanation 0: he's staring very intently,
# Argmax: nó đang nhìn chằm chằm rất chăm chú,
# Sampling: nó đang nhìn chằm chằm rất chăm chú,
#   vinai: anh ấy nhìn chằm chằm,
#   gemini: nó đang nhìn chằm chằm rất chăm chú,
#   ggtrans: anh ấy đang nhìn chằm chằm rất chăm chú,
#   gpt: Anh ấy đang nhìn rất chăm chú,
#
# ====================================================================================================
# ID: 104725002
# Question: What kind of birds are these?
# Answers: seagulls
# Explanation 0: they have orange beaks, long legs, and white heads, and are standing near the ocean
# Argmax: chúng có mỏ màu cam, chân dài, đầu trắng và đang đứng gần biển
# Sampling: chúng có mỏ màu cam, chân dài, đầu trắng và đang đứng gần biển
#   vinai: chúng có mỏ màu cam, chân dài và đầu trắng, và đang đứng gần đại dương
#   gemini: chúng có mỏ màu cam, chân dài, đầu trắng và đang đứng gần biển
#   ggtrans: chúng có mỏ màu cam, chân dài, đầu trắng và đang đứng gần biển
#   gpt: chúng có mỏ màu cam, chân dài, và đầu trắng, đang đứng gần bờ biển
#
# ====================================================================================================
# ID: 196747000
# Question: What sport are they doing?
# Answers: skateboarding
# Explanation 0: all of the kids are on skateboards
# Argmax: tất cả bọn trẻ đều đang trượt ván
# Sampling: tất cả bọn trẻ đều đang trượt ván
#   vinai: Tất cả bọn trẻ đều đang trượt ván.
#   gemini: tất cả trẻ em đều đang ở trên ván trượt
#   ggtrans: tất cả bọn trẻ đều đang trượt ván
#   gpt: tất cả các đứa trẻ đều đang trên ván trượt
#
# ====================================================================================================
# ID: 305832001
# Question: What kind of juice is made with this fruit?
# Answers: orange
# Explanation 0: that is the juice you get from oranges
# Argmax: đó là nước ép bạn có được từ cam
# Sampling: đó là nước ép bạn nhận được từ cam
#   vinai: đó là nước ép bạn lấy từ cam
#   gemini: đó là nước ép bạn nhận được từ cam
#   ggtrans: đó là nước ép bạn có được từ cam
#   gpt: đó là nước trái cây bạn nhận được từ những quả cam
#
# ====================================================================================================
# ID: 385940002
# Question: What kind of vehicle is this?
# Answers: train
# Explanation 0: the vehicle is on the train tracks
# Argmax: phương tiện đang ở trên đường ray tàu hỏa
# Sampling: phương tiện đang ở trên đường ray tàu hỏa
#   vinai: Chiếc xe đang ở trên đường ray.
#   gemini: phương tiện đang ở trên đường ray tàu hỏa
#   ggtrans: chiếc xe đang ở trên đường ray xe lửa
#   gpt: phương tiện đang trên đường ray tàu hỏa
#
# ====================================================================================================
# ID: 359760000
# Question: Is this a grassland?
# Answers: yes
# Explanation 0: there is grass and trees everywhere
# Argmax: có cỏ và cây ở khắp mọi nơi
# Sampling: có cỏ và cây ở khắp nơi
#   vinai: cỏ và cây cối ở khắp mọi nơi
#   gemini: có cỏ và cây cối ở khắp mọi nơi
#   ggtrans: có cỏ và cây ở khắp mọi nơi
#   gpt: có cỏ và cây ở khắp nơi
#
# ====================================================================================================
# ID: 46242009
# Question: Overcast or sunny?
# Answers: overcast
# Explanation 0: the sun is not out here
# Argmax: Mặt trời không ở ngoài này.
# Sampling: Mặt trời không ở ngoài này.
#   vinai: Mặt trời không ở ngoài này.
#   gemini: mặt trời không chiếu sáng ở đây
#   ggtrans: mặt trời không ở ngoài này
#   gpt: mặt trời không xuất hiện ở đây
#
# ====================================================================================================
# ID: 66273001
# Question: Which room is this?
# Answers: kitchen
# Explanation 0: a man is putting a pizza into the oven
# Argmax: một người đàn ông đang cho bánh pizza vào lò nướng
# Sampling: một người đàn ông đang đặt một bánh pizza vào lò nướng
#   vinai: một người đàn ông đang đặt một bánh pizza vào lò nướng
#   gemini: một người đàn ông đang bỏ pizza vào lò nướng
#   ggtrans: một người đàn ông đang cho bánh pizza vào lò nướng
#   gpt: một người đàn ông đang cho một chiếc pizza vào lò nướng
#
# ====================================================================================================
# ID: 341189000
# Question: What sport are they playing?
# Answers: tennis
# Explanation 0: the man kneels on a felt court and holds a round racket with handle
# Argmax: người đàn ông quỳ trên sân nỉ và cầm một cây vợt tròn có tay cầm
# Sampling: người đàn ông quỳ trên sân felt và cầm một cây vợt hình tròn có tay cầm
#   vinai: Người đàn ông quỳ trên một sân nỉ và cầm một cây vợt tròn có tay cầm
#   gemini: người đàn ông quỳ trên một sân đấu bằng nỉ và cầm một ván tròn có tay cầm
#   ggtrans: người đàn ông quỳ trên sân nỉ và cầm một cây vợt tròn có tay cầm
#   gpt: người đàn ông quỳ trên sân felt và cầm một cây vợt hình tròn có tay cầm
#
# ====================================================================================================
# ID: 407214000
# Question: What kind of room is this?
# Answers: bathroom
# Explanation 0: there is a toilet beside a paper roll holder and a tiled floor with a drain
# Argmax: có một cái bồn cầu bên cạnh một giá đựng giấy cuộn và một sàn lát gạch có cống thoát nước
# Sampling: có một cái bồn cầu bên cạnh một giá đựng giấy cuộn và một sàn lát gạch có cống thoát nước
#   vinai: có một nhà vệ sinh bên cạnh một người giữ cuộn giấy và sàn lát gạch có ống thoát nước
#   gemini: có một cái bồn cầu bên cạnh một giá đựng giấy cuộn và một sàn lát gạch có cống thoát nước
#   ggtrans: có nhà vệ sinh bên cạnh giá đựng cuộn giấy và sàn lát gạch có cống thoát nước
#   gpt: có một cái bồn cầu bên cạnh một giá đỡ giấy và một sàn gạch có lỗ thoát nước
#
# Explanation 1: there is a toilet
# Argmax: có một nhà vệ sinh
# Sampling: có một cái bồn cầu
#   vinai: có một nhà vệ sinh
#   gemini: có một cái bồn cầu
#   ggtrans: có một nhà vệ sinh
#   gpt: có một cái bồn cầu
#
# ====================================================================================================
# ID: 180494003
# Question: Is it night time?
# Answers: yes
# Explanation 0: there is no sunlight illuminating the scene
# Argmax: không có ánh sáng mặt trời chiếu sáng khung cảnh
# Sampling: không có ánh sáng mặt trời chiếu sáng cảnh vật
#   vinai: không có ánh sáng mặt trời chiếu sáng cảnh
#   gemini: không có ánh sáng mặt trời chiếu sáng cảnh vật
#   ggtrans: không có ánh sáng mặt trời chiếu sáng khung cảnh
#   gpt: không có ánh sáng mặt trời chiếu sáng cảnh vật
#
# ====================================================================================================
# ID: 453989000
# Question: Does it look like it is going to rain?
# Answers: no
# Explanation 0: the sky is very clear
# Argmax: bầu trời rất trong xanh
# Sampling: trời rất trong xanh
#   vinai: Bầu trời rất trong.
#   gemini: bầu trời rất quang đãng
#   ggtrans: bầu trời rất trong xanh
#   gpt: trời rất trong xanh
#
# ====================================================================================================
# ID: 568628001
# Question: Is the toilet clean?
# Answers: no
# Explanation 0: the toilet has dirt on it and is sitting in an old, abandoned bathroom
# Argmax: nhà vệ sinh có vết bẩn và nằm trong một phòng tắm cũ bị bỏ hoang
# Sampling: nhà vệ sinh có bụi bẩn trên đó và đang ngồi trong một phòng tắm cũ, bị bỏ rơi
#   vinai: nhà vệ sinh có bụi bẩn trên đó và đang ngồi trong một phòng tắm cũ, bị bỏ rơi
#   gemini: bồn cầu có bẩn và đang ở trong một phòng tắm cũ, bỏ hoang
#   ggtrans: nhà vệ sinh có vết bẩn và nằm trong một phòng tắm cũ bị bỏ hoang
#   gpt: nhà vệ sinh bẩn và đang nằm ở một nhà tắm cũ, bị bỏ hoang
#
# ====================================================================================================
# ID: 479825003
# Question: Is the plane flying?
# Answers: no
# Explanation 0: it is sitting on the ground with it's tail down parked next to a building
# Argmax: nó đang ngồi trên mặt đất với cái đuôi cụp xuống đậu cạnh một tòa nhà
# Sampling: nó đang ngồi trên mặt đất với cái đuôi cụp xuống đậu cạnh một tòa nhà
#   vinai: nó đang ngồi trên mặt đất với cái đuôi của nó xuống đậu bên cạnh một tòa nhà
#   gemini: nó đang đậu trên mặt đất với đuôi hướng xuống, đậu cạnh một tòa nhà
#   ggtrans: nó đang ngồi trên mặt đất với cái đuôi cụp xuống đậu cạnh một tòa nhà
#   gpt: nó đang ngồi trên mặt đất với đuôi hạ thấp đậu bên cạnh một tòa nhà
#
# ====================================================================================================
# ID: 484217002
# Question: Does the vase have a design on it?
# Answers: no
# Explanation 0: it is a long cylinder of clear glass
# Argmax: nó là một hình trụ dài bằng thủy tinh trong suốt
# Sampling: nó là một hình trụ dài bằng thủy tinh trong suốt
#   vinai: nó là một hình trụ dài bằng thủy tinh trong suốt
#   gemini: đó là một hình trụ dài bằng kính trong suốt
#   ggtrans: nó là một hình trụ dài bằng thủy tinh trong suốt
#   gpt: đó là một hình trụ dài bằng kính trong suốt
#
# ====================================================================================================
# ID: 88241010
# Question: Does the puppy and the stuffed bear have the same colored nose?
# Answers: yes
# Explanation 0: they are both brown and black
# Argmax: chúng đều có màu nâu và đen
# Sampling: chúng đều có màu nâu và đen
#   vinai: chúng đều có màu nâu và đen
#   gemini: cả hai đều có màu nâu và đen
#   ggtrans: chúng đều có màu nâu và đen
#   gpt: Chúng đều có màu nâu và đen.
#
# ====================================================================================================
# ID: 77979002
# Question: What are the animals doing?
# Answers: walking
# Explanation 0: you can see their legs are in motion
# Argmax: Bạn có thể thấy chân của chúng đang chuyển động.
# Sampling: bạn có thể thấy chân của chúng đang chuyển động
#   vinai: Bạn có thể thấy chân của chúng đang chuyển động.
#   gemini: bạn có thể thấy chân của chúng đang chuyển động
#   ggtrans: bạn có thể thấy chân của họ đang chuyển động
#   gpt: bạn có thể thấy chân của chúng đang chuyển động
#
# ====================================================================================================
# ID: 329242000
# Question: What is the boy doing?
# Answers: brushing teeth
# Explanation 0: he has a toothbrush in his mouth
# Argmax: cậu ấy có bàn chải đánh răng trong miệng
# Sampling: anh ấy có một chiếc bàn chải đánh răng trong miệng
#   vinai: Hắn có bàn chải đánh răng trong miệng.
#   gemini: cậu ấy có bàn chải đánh răng trong miệng
#   ggtrans: anh ấy có một chiếc bàn chải đánh răng trong miệng
#   gpt: Cậu ấy có một chiếc bàn chải trong miệng
#
# ====================================================================================================
# ID: 193062000
# Question: Would a vegetarian eat this?
# Answers: no
# Explanation 0: there is a lot of meat on the sandwich
# Argmax: Có rất nhiều thịt trên bánh sandwich.
# Sampling: Có rất nhiều thịt trên bánh sandwich.
#   vinai: Có rất nhiều thịt trên bánh sandwich.
#   gemini: có rất nhiều thịt trong bánh sandwich
#   ggtrans: có rất nhiều thịt trên bánh sandwich
#   gpt: có nhiều thịt trên bánh mì này
#
# ====================================================================================================
# ID: 519273006
# Question: Does the kite have a string on it?
# Answers: yes
# Explanation 0: the man is anchoring the kite with string to rings in both hands
# Argmax: Người đàn ông đang cố định diều bằng dây với các vòng ở cả hai tay
# Sampling: Người đàn ông đang cố định diều bằng dây với các vòng ở cả hai tay
#   vinai: người đàn ông đang neo diều với chuỗi để nhẫn trong cả hai tay
#   gemini: Người đàn ông đang cố định diều bằng dây với các vòng ở cả hai tay
#   ggtrans: người đàn ông đang neo diều bằng dây vào vòng ở cả hai tay
#   gpt: người đàn ông đang buộc diều bằng dây vào các vòng trong cả hai tay
#
# ====================================================================================================
# ID: 204333002
# Question: What branch of the military flew this plane?
# Answers: air force
# Explanation 0: british air force planes have a bulls eye symbol with a blue background
# Argmax: Máy bay của Không quân Anh có biểu tượng mắt bò với nền màu xanh.
# Sampling: máy bay của không quân hoàng gia Anh có biểu tượng tâm điểm với nền màu xanh lam
#   vinai: Máy bay của Không quân Anh có biểu tượng mắt bò với nền màu xanh.
#   gemini: máy bay của không quân hoàng gia Anh có biểu tượng tâm điểm với nền màu xanh lam
#   ggtrans: máy bay của lực lượng không quân Anh có biểu tượng mắt bò trên nền màu xanh
#   gpt: Máy bay của lực lượng không quân Anh có biểu tượng vòng tròn với nền xanh.
#
# ====================================================================================================
# ID: 167599010
# Question: What room is this?
# Answers: bathroom
# Explanation 0: there is a white toilet and sink in it
# Argmax: có một bồn cầu và bồn rửa mặt màu trắng trong đó
# Sampling: có một cái bồn cầu và bồn rửa mặt màu trắng trong đó
#   vinai: có một nhà vệ sinh màu trắng và bồn rửa trong đó
#   gemini: có một bồn cầu và bồn rửa mặt màu trắng trong đó
#   ggtrans: có một cái bồn cầu màu trắng và chìm trong đó
#   gpt: có một cái bồn cầu và bồn rửa mặt màu trắng trong đó
#
# ====================================================================================================
# ID: 402041002
# Question: What type of show is going on?
# Answers: circus
# Explanation 0: there are elephants on tables
# Argmax: Có voi trên bàn kìa.
# Sampling: Có voi trên bàn kìa.
#   vinai: Có voi trên bàn kìa.
#   gemini: có voi trên bàn
#   ggtrans: có những con voi trên bàn
#   gpt: có voi trên bàn
#
# ====================================================================================================
# ID: 550703000
# Question: What type of animal is in the water?
# Answers: elephant
# Explanation 0: it is very big with tusks
# Argmax: nó rất to với những chiếc ngà
# Sampling: nó rất lớn với ngà
#   vinai: nó rất lớn với ngà
#   gemini: nó rất lớn với ngà
#   ggtrans: nó rất to với những chiếc ngà
#   gpt: nó rất to với ngà.
#
# ====================================================================================================
# ID: 208479003
# Question: What is the tennis player wearing on his head?
# Answers: headband
# Explanation 0: a band of fabric is wrapped around his head
# Argmax: một dải vải quấn quanh đầu anh ấy
# Sampling: một dải vải được quấn quanh đầu của anh ấy
#   vinai: một dải vải được quấn quanh đầu anh ta
#   gemini: một dải vải được quấn quanh đầu của anh ấy
#   ggtrans: một dải vải quấn quanh đầu anh ấy
#   gpt: một dải vải quấn quanh đầu anh ấy
#
# ====================================================================================================
# ID: 526542000
# Question: Are the trees bare?
# Answers: no
# Explanation 0: some of the trees still have green needles on them and are covered in snow
# Argmax: một số cây vẫn còn lá kim xanh và bị tuyết bao phủ
# Sampling: một số cây vẫn còn lá kim xanh và được phủ tuyết
#   vinai: Một số cây vẫn còn có kim màu xanh lá cây trên chúng và được bao phủ trong tuyết
#   gemini: một số cây vẫn còn lá kim màu xanh trên đó và được phủ tuyết
#   ggtrans: một số cây vẫn còn lá kim xanh và bị tuyết bao phủ
#   gpt: một số cây vẫn còn lá kim xanh và được phủ tuyết
#
# ====================================================================================================
# ID: 406187002
# Question: Is this black and white?
# Answers: yes
# Explanation 0: there is no color in the image
# Argmax: không có màu sắc trong hình ảnh
# Sampling: không có màu trong ảnh
#   vinai: không có màu trong ảnh
#   gemini: không có màu trong hình
#   ggtrans: không có màu sắc trong hình ảnh
#   gpt: không có màu trong hình ảnh
#
# ====================================================================================================
# ID: 365312000
# Question: What room is this?
# Answers: kitchen
# Explanation 0: there is a refrigerator there
# Argmax: Có một cái tủ lạnh ở đó.
# Sampling: ở đó có một cái tủ lạnh
#   vinai: Có một cái tủ lạnh ở đó.
#   gemini: có tủ lạnh ở đó
#   ggtrans: ở đó có một cái tủ lạnh
#   gpt: Có một cái tủ lạnh ở đó.
#
# ====================================================================================================
# ID: 122259002
# Question: What kind of wine are they drinking?
# Answers: white
# Explanation 0: it looks very light colored
# Argmax: nó có vẻ rất nhạt màu
# Sampling: nó trông rất sáng màu
#   vinai: nó trông rất sáng màu
#   gemini: nó có vẻ rất nhạt màu
#   ggtrans: nó trông rất sáng màu
#   gpt: nó trông có màu rất nhạt
#
# ====================================================================================================
# ID: 74846007
# Question: What is the man doing?
# Answers: skiing
# Explanation 0: he is wearing skis and riding down a mountain
# Argmax: anh ấy đang mặc ván trượt và đi xuống núi
# Sampling: Ông đang mặc ván trượt và cưỡi xuống một ngọn núi.
#   vinai: Ông đang mặc ván trượt và cưỡi xuống một ngọn núi.
#   gemini: anh ấy đang đeo ván trượt và trượt xuống núi
#   ggtrans: anh ấy đang mặc ván trượt và đi xuống núi
#   gpt: anh ấy đang mang giày trượt tuyết và trượt xuống núi
#
# ====================================================================================================
# ID: 101697000
# Question: Is the bird missing a leg?
# Answers: no
# Explanation 0: it has two legs
# Argmax: nó có hai chân
# Sampling: nó có hai chân
#   vinai: nó có hai chân
#   gemini: nó có hai chân
#   ggtrans: nó có hai chân
#   gpt: nó có hai chân
#
# ====================================================================================================
# ID: 119686000
# Question: Is it raining?
# Answers: no
# Explanation 0: it is dry outside and there is no rain present
# Argmax: bên ngoài trời khô ráo và không có mưa
# Sampling: bên ngoài khô ráo và không có mưa
#   vinai: bên ngoài khô ráo và không có mưa
#   gemini: bên ngoài khô ráo và không có mưa
#   ggtrans: bên ngoài trời khô ráo và không có mưa
#   gpt: ngoài trời khô ráo và không có mưa nào cả
#
# ====================================================================================================
# ID: 506821000
# Question: What animal is this?
# Answers: giraffe
# Explanation 0: of his spots and long head and distinctive giraffe-like features
# Argmax: vì những đốm và cái đầu dài và những đặc điểm giống hươu cao cổ đặc trưng
# Sampling: vì những đốm và cái đầu dài và những đặc điểm giống hươu cao cổ đặc trưng
#   vinai: của mình đốm và đầu dài và đặc điểm giống như hươu cao cổ đặc biệt
#   gemini: vì những đốm và cái đầu dài và những đặc điểm giống hươu cao cổ đặc trưng
#   ggtrans: về những đốm, cái đầu dài và những đặc điểm giống hươu cao cổ đặc biệt của anh ấy
#   gpt: về các đốm của nó và đầu dài cùng các đặc điểm đặc trưng giống hươu cao cổ
#
# ====================================================================================================
# ID: 488422007
# Question: What room is this?
# Answers: kitchen
# Explanation 0: there are appliances, a counter and breakfast seating
# Argmax: có các thiết bị, quầy và chỗ ngồi ăn sáng
# Sampling: có thiết bị, một quầy và chỗ ngồi ăn sáng
#   vinai: có các thiết bị, quầy và chỗ ngồi ăn sáng
#   gemini: có những thiết bị, một quầy và chỗ ngồi ăn sáng
#   ggtrans: có các thiết bị, quầy và chỗ ngồi ăn sáng
#   gpt: có thiết bị, một quầy và chỗ ngồi ăn sáng
#
# Explanation 1: there is a coffee machine, eating area, and cupboards
# Argmax: có máy pha cà phê, khu vực ăn uống và tủ đựng đồ
# Sampling: có máy pha cà phê, khu vực ăn uống và tủ đựng đồ
#   vinai: có một máy pha cà phê, khu vực ăn uống và tủ
#   gemini: có máy pha cà phê, khu vực ăn uống và tủ
#   ggtrans: có máy pha cà phê, khu vực ăn uống và tủ đựng đồ
#   gpt: có máy pha cà phê, khu vực ăn uống và tủ đựng đồ
#
# ====================================================================================================
# ID: 88723000
# Question: Is this a small stove?
# Answers: yes
# Explanation 0: the stove is in a small area among small kitchen hardware
# Argmax: bếp nằm ở một khu vực nhỏ giữa các thiết bị nhà bếp nhỏ
# Sampling: Cái bếp nằm trong một khu vực nhỏ giữa các thiết bị nhà bếp nhỏ.
#   vinai: Bếp nằm trong một khu vực nhỏ giữa các phần cứng nhà bếp nhỏ
#   gemini: cái bếp nằm trong một khu vực nhỏ giữa các thiết bị nhà bếp nhỏ
#   ggtrans: bếp nằm ở một khu vực nhỏ giữa các thiết bị nhà bếp nhỏ
#   gpt: Cái bếp nằm trong một khu vực nhỏ giữa các thiết bị nhà bếp nhỏ.
#
# ====================================================================================================
# ID: 131351002
# Question: What is the floor made of?
# Answers: tile
# Explanation 0: square tiles are grouted on the ground
# Argmax: gạch vuông được trát vữa trên mặt đất
# Sampling: gạch vuông được trát vữa trên mặt đất
#   vinai: gạch vuông được phun vữa trên mặt đất
#   gemini: gạch vuông được trát vữa trên mặt đất
#   ggtrans: gạch vuông được trát vữa trên mặt đất
#   gpt: các viên gạch vuông được chà mạch trên mặt đất
#
# ====================================================================================================
# ID: 480012004
# Question: Does one animal have horns?
# Answers: yes
# Explanation 0: the cow has pointed items coming from his head
# Argmax: con bò có những vật nhọn mọc ra từ đầu
# Sampling: con bò có những vật nhọn mọc ra từ đầu
#   vinai: con bò đã chỉ mục đến từ đầu của mình
#   gemini: con bò có những vật nhọn mọc ra từ đầu
#   ggtrans: con bò có vật nhọn phát ra từ đầu nó
#   gpt: Con bò có những cái nhọn mọc ra từ đầu của nó.
#
# ====================================================================================================
# ID: 462516000
# Question: What sport is he playing here?
# Answers: baseball
# Explanation 0: it looks he is pose of  thow the ball to fielder
# Argmax: có vẻ như anh ấy đang ở tư thế ném bóng cho người bắt bóng
# Sampling: có vẻ như anh ấy đang trong tư thế ném bóng cho người điều khiển
#   vinai: Có vẻ như anh ta là tư thế của Throw the ball to fielder
#   gemini: có vẻ như anh ấy đang ở tư thế ném bóng cho người bắt bóng
#   ggtrans: có vẻ như anh ấy đang trong tư thế ném bóng cho người điều khiển
#   gpt: Hình như anh ấy đang tạo dáng để ném bóng cho cầu thủ ngoài sân.
#
# ====================================================================================================
# ID: 513430000
# Question: Does this meal look healthy?
# Answers: yes
# Explanation 0: it is full of fruit
# Argmax: Nó đầy trái cây.
# Sampling: nó có đầy trái cây
#   vinai: Nó đầy trái cây.
#   gemini: nó đầy trái cây
#   ggtrans: nó có đầy trái cây
#   gpt: Nó đầy trái cây
#
# ====================================================================================================
# ID: 567199000
# Question: Does the child have a hat on?
# Answers: no
# Explanation 0: all of the child's hair is exposed
# Argmax: toàn bộ tóc của đứa trẻ lộ ra ngoài
# Sampling: tất cả tóc của đứa trẻ được tiếp xúc
#   vinai: tất cả tóc của đứa trẻ được tiếp xúc
#   gemini: tất cả tóc của đứa trẻ đều lộ ra
#   ggtrans: toàn bộ tóc của đứa trẻ lộ ra ngoài
#   gpt: tất cả tóc của đứa trẻ đều lộ ra
#
# ====================================================================================================
# ID: 308772000
# Question: What is this person doing?
# Answers: snowboarding
# Explanation 0: the man has a snowboard strapped to one foot
# Argmax: người đàn ông có một chiếc ván trượt tuyết buộc vào một chân
# Sampling: người đàn ông có một ván trượt tuyết gắn liền với một chân
#   vinai: người đàn ông có một ván trượt tuyết gắn liền với một chân
#   gemini: người đàn ông có một tấm ván trượt tuyết buộc vào một chân
#   ggtrans: người đàn ông có một chiếc ván trượt tuyết buộc vào một chân
#   gpt: người đàn ông có một chiếc ván tuyết buộc vào một chân
#
# ====================================================================================================
# ID: 110252000
# Question: What kind of fruit is being sold at this stand?
# Answers: bananas
# Explanation 0: they are yellow and in bunches
# Argmax: chúng có màu vàng và được xếp thành từng chùm
# Sampling: chúng có màu vàng và mọc thành chùm
#   vinai: chúng có màu vàng và thành chùm
#   gemini: chúng có màu vàng và được xếp thành từng chùm
#   ggtrans: chúng có màu vàng và mọc thành chùm
#   gpt: chúng màu vàng và có chùm
#
# ====================================================================================================
# ID: 280898003
# Question: What is the bus number?
# Answers: 28
# Explanation 0: it is shown on the digital display on the front
# Argmax: nó được hiển thị trên màn hình kỹ thuật số ở mặt trước
# Sampling: nó được hiển thị trên màn hình kỹ thuật số ở mặt trước
#   vinai: nó được hiển thị trên màn hình kỹ thuật số ở mặt trước
#   gemini: nó được hiển thị trên màn hình kỹ thuật số ở phía trước
#   ggtrans: nó được hiển thị trên màn hình kỹ thuật số ở mặt trước
#   gpt: Nó được hiển thị trên màn hình kỹ thuật số ở phía trước.
#
# ====================================================================================================
# ID: 555811001
# Question: Is the window open?
# Answers: no
# Explanation 0: there is a pane of glass separating the inside from the outside
# Argmax: có một tấm kính ngăn cách bên trong và bên ngoài
# Sampling: có một tấm kính ngăn cách bên trong với bên ngoài
#   vinai: có một tấm kính ngăn cách bên trong với bên ngoài
#   gemini: có một tấm kính ngăn cách bên trong với bên ngoài
#   ggtrans: có một tấm kính ngăn cách bên trong và bên ngoài
#   gpt: có một tấm kính ngăn cách bên trong với bên ngoài
#
# ====================================================================================================
# ID: 100638008
# Question: Is this there an advertisement in the background?
# Answers: no
# Explanation 0: this is a wii video game
# Argmax: đây là một trò chơi điện tử wii
# Sampling: đây là một trò chơi điện tử wii
#   vinai: đây là một trò chơi điện tử wii
#   gemini: đây là một trò chơi điện tử wii
#   ggtrans: đây là một trò chơi điện tử wii
#   gpt: đây là một trò chơi điện tử Wii
#
# ====================================================================================================
# ID: 388911003
# Question: What room is this going to become?
# Answers: bathroom
# Explanation 0: there is a sink and toilet ready to be installed
# Argmax: có một bồn rửa và nhà vệ sinh đã sẵn sàng để lắp đặt
# Sampling: có bồn rửa mặt và bồn cầu đã sẵn sàng để lắp đặt
#   vinai: có một bồn rửa và nhà vệ sinh sẵn sàng để được cài đặt
#   gemini: có bồn rửa mặt và bồn cầu đã sẵn sàng để lắp đặt
#   ggtrans: có một bồn rửa và nhà vệ sinh đã sẵn sàng để lắp đặt
#   gpt: có một cái bồn rửa và toilet sẵn sàng để lắp đặt
#
# ====================================================================================================
# ID: 533176000
# Question: Is it snowing?
# Answers: no
# Explanation 0: there is no snow in the air, only on the ground
# Argmax: không có tuyết trong không khí, chỉ có trên mặt đất
# Sampling: không có tuyết trong không khí, chỉ có trên mặt đất
#   vinai: không có tuyết trong không khí, chỉ trên mặt đất
#   gemini: không có tuyết trong không khí, chỉ có trên mặt đất
#   ggtrans: không có tuyết trong không khí, chỉ có trên mặt đất
#   gpt: Không có tuyết trong không khí, chỉ có trên mặt đất
#
# ====================================================================================================
# ID: 551036002
# Question: Is the bed made?
# Answers: no
# Explanation 0: making a bed is pointless, this kid already gets it
# Argmax: làm giường là vô ích, đứa trẻ này đã hiểu điều đó
# Sampling: làm một chiếc giường là vô nghĩa, đứa trẻ này đã được nó
#   vinai: làm một chiếc giường là vô nghĩa, đứa trẻ này đã được nó
#   gemini: trải giường là vô ích, đứa trẻ này đã hiểu rồi
#   ggtrans: dọn giường thật vô nghĩa, đứa trẻ này đã hiểu rồi
#   gpt: làm giường là vô ích, đứa trẻ này đã hiểu điều đó
#
# ====================================================================================================
# ID: 341029001
# Question: Does this pizza look burnt?
# Answers: no
# Explanation 0: it is not blackened
# Argmax: nó không bị đen
# Sampling: nó không bị đen
#   vinai: nó không bị đen
#   gemini: nó không bị đen
#   ggtrans: nó không bị đen
#   gpt: nó không bị đen
#
# ====================================================================================================
# ID: 424300000
# Question: Does this photograph reveal an emotional sensibility?
# Answers: yes
# Explanation 0: there are different gradients of color
# Argmax: có nhiều sắc độ màu khác nhau
# Sampling: có nhiều độ dốc màu khác nhau
#   vinai: có các gradient màu khác nhau
#   gemini: có nhiều sắc độ màu khác nhau
#   ggtrans: có nhiều độ dốc màu khác nhau
#   gpt: Có nhiều độ gradient màu khác nhau
#
# ====================================================================================================
# ID: 164462001
# Question: What are they playing?
# Answers: tennis
# Explanation 0: they have rackets and are swinging at a yellow ball
# Argmax: họ có vợt và đang vung vào một quả bóng màu vàng
# Sampling: họ có vợt và đang đu tại một quả bóng màu vàng
#   vinai: họ có vợt và đang đu tại một quả bóng màu vàng
#   gemini: họ có vợt và đang đánh vào một quả bóng vàng
#   ggtrans: họ có vợt và đang vung vào một quả bóng màu vàng
#   gpt: Họ có vợt và đang đánh vào một quả bóng màu vàng
#
# ====================================================================================================
# ID: 500005001
# Question: What type of court is this?
# Answers: tennis
# Explanation 0: there is a net in front of the player
# Argmax: có một lưới trước mặt người chơi
# Sampling: có một lưới trước mặt người chơi
#   vinai: có một mạng lưới ở phía trước của các cầu thủ
#   gemini: có một lưới trước mặt người chơi
#   ggtrans: có một cái lưới ở phía trước người chơi
#   gpt: Có một cái lưới trước người chơi.
#
# ====================================================================================================
# ID: 413128006
# Question: Is the grate open?
# Answers: no
# Explanation 0: the gate is closed
# Argmax: Cổng đã đóng.
# Sampling: cửa đã đóng
#   vinai: Cổng đã đóng.
#   gemini: cổng đóng
#   ggtrans: cánh cổng đã đóng
#   gpt: cửa đã đóng
#
# ====================================================================================================
# ID: 116431001
# Question: Is the man serving the ball?
# Answers: yes
# Explanation 0: he has just thrown the ball into the air and is about to hit it with his racket
# Argmax: anh ta vừa ném quả bóng lên không trung và chuẩn bị đánh nó bằng vợt
# Sampling: Anh ấy vừa ném quả bóng vào không trung và chuẩn bị đánh nó bằng vợt của mình.
#   vinai: Anh ấy vừa ném quả bóng vào không trung và chuẩn bị đánh nó bằng vợt của mình.
#   gemini: anh ấy vừa ném bóng lên không trung và sắp đánh nó bằng vợt
#   ggtrans: anh ta vừa ném quả bóng lên không trung và chuẩn bị đánh nó bằng vợt
#   gpt: Ông ấy vừa ném bóng lên không trung và sắp đánh nó bằng vợt của mình
#
# Explanation 1: he is jumping into the air while hitting it
# Argmax: anh ta đang nhảy lên không trung trong khi đánh nó
# Sampling: anh ấy đang nhảy lên không trung trong khi đánh nó
#   vinai: anh ấy đang nhảy lên không trung trong khi đánh nó
#   gemini: anh ấy đang nhảy lên không trung khi đánh bóng
#   ggtrans: anh ta đang nhảy lên không trung trong khi đánh nó
#   gpt: Ông ấy đang nhảy lên không trung trong khi đánh bóng
#
# ====================================================================================================
# ID: 362284001
# Question: Is the elephant eating a tree?
# Answers: no
# Explanation 0: it is carrying people around
# Argmax: nó đang chở mọi người đi khắp nơi
# Sampling: Nó chở người đi khắp nơi.
#   vinai: Nó chở người đi khắp nơi.
#   gemini: nó đang chở người xung quanh
#   ggtrans: nó đang chở mọi người đi khắp nơi
#   gpt: nó đang chở người quanh đây
#
# ====================================================================================================
# ID: 19552001
# Question: What sport is he playing?
# Answers: tennis
# Explanation 0: he is alone on a court holding a tennis racket over his head, and there is an advertisement for lacoste behind him
# Argmax: anh ta đứng một mình trên sân với một cây vợt tennis trên đầu và có một quảng cáo về giày lacoste đằng sau anh ta
# Sampling: một mình trên sân, tay cầm vợt tennis trên đầu, đằng sau có một quảng cáo về rượu lacoste.
#   vinai: một mình trên sân, tay cầm vợt tennis trên đầu, đằng sau có một quảng cáo về rượu lacoste.
#   gemini: anh ấy đang ở một mình trên sân, cầm một cây vợt quần vợt trên đầu, và có một quảng cáo cho lacoste phía sau anh ấy
#   ggtrans: anh ta đứng một mình trên sân với một cây vợt tennis trên đầu và có một quảng cáo về giày lacoste đằng sau anh ta
#   gpt: anh ấy đứng một mình trên sân cầm một cây vợt tennis trên đầu, và có một quảng cáo cho Lacoste phía sau lưng anh ấy
#
# ====================================================================================================
# ID: 529061001
# Question: Is the weather rainy?
# Answers: yes
# Explanation 0: the window is wet
# Argmax: cửa sổ bị ướt
# Sampling: cửa sổ bị ướt
#   vinai: cửa sổ bị ướt
#   gemini: cửa sổ bị ướt
#   ggtrans: cửa sổ ướt
#   gpt: Cửa sổ ướt
#
# ====================================================================================================
# ID: 273363011
# Question: What kind of sport is this?
# Answers: tennis
# Explanation 0: the guy is hitting a ball on a tennis court
# Argmax: anh chàng đang đánh bóng trên sân tennis
# Sampling: người đàn ông đang đánh bóng trên sân quần vợt
#   vinai: Anh ta đang đánh bóng trên sân tennis.
#   gemini: người đàn ông đang đánh bóng trên sân quần vợt
#   ggtrans: anh chàng đang đánh bóng trên sân tennis
#   gpt: cậu ấy đang đánh một quả bóng trên sân quần vợt
#
# ====================================================================================================
# ID: 44842001
# Question: Where was the pic taken?
# Answers: airport
# Explanation 0: it is an airplane
# Argmax: Nó là một chiếc máy bay.
# Sampling: nó là một chiếc máy bay
#   vinai: Nó là một chiếc máy bay.
#   gemini: đó là một máy bay
#   ggtrans: nó là một chiếc máy bay
#   gpt: đó là một chiếc máy bay
#
# ====================================================================================================
# ID: 545534002
# Question: Is this taken at night?
# Answers: no
# Explanation 0: the sun is shining
# Argmax: mặt trời đang chiếu sáng
# Sampling: mặt trời đang chiếu sáng
#   vinai: Mặt trời đang chiếu sáng.
#   gemini: mặt trời đang chiếu sáng
#   ggtrans: mặt trời đang chiếu sáng
#   gpt: mặt trời đang chiếu sáng
#
# ====================================================================================================
# ID: 71313000
# Question: Does the dog have a shadow?
# Answers: yes
# Explanation 0: the sun is creating a shadow under the dog
# Argmax: mặt trời đang tạo ra cái bóng dưới con chó
# Sampling: mặt trời đang tạo ra một cái bóng dưới con chó
#   vinai: mặt trời đang tạo ra một cái bóng dưới con chó
#   gemini: mặt trời đang tạo ra một cái bóng dưới con chó
#   ggtrans: mặt trời đang tạo ra cái bóng dưới con chó
#   gpt: mặt trời đang tạo ra bóng dưới con chó
#
# ====================================================================================================
# ID: 330865004
# Question: What is the man doing?
# Answers: skiing
# Explanation 0: the snow from the slope is kicking up behind the man as he slides down the mountain
# Argmax: tuyết từ trên sườn dốc tung lên phía sau người đàn ông khi anh ta trượt xuống núi
# Sampling: tuyết từ trên sườn dốc tung lên phía sau người đàn ông khi anh ta trượt xuống núi
#   vinai: tuyết từ sườn dốc đang đá lên phía sau người đàn ông khi ông trượt xuống núi
#   gemini: tuyết từ sườn dốc đang bay lên phía sau người đàn ông khi anh ta trượt xuống núi
#   ggtrans: tuyết từ trên sườn dốc tung lên phía sau người đàn ông khi anh ta trượt xuống núi
#   gpt: tuyết từ sườn đồi đang bay lên phía sau người đàn ông khi anh ấy trượt xuống núi
#
# ====================================================================================================
# ID: 15153002
# Question: What sport is being played?
# Answers: tennis
# Explanation 0: they are using tennis rackets and tennis balls on a tennis court
# Argmax: họ đang sử dụng vợt tennis và bóng tennis trên sân tennis
# Sampling: họ đang sử dụng vợt quần vợt và bóng quần vợt trên sân quần vợt
#   vinai: họ đang sử dụng vợt tennis và bóng tennis trên sân tennis
#   gemini: họ đang sử dụng vợt quần vợt và bóng quần vợt trên sân quần vợt
#   ggtrans: họ đang sử dụng vợt tennis và bóng tennis trên sân tennis
#   gpt: họ đang sử dụng vợt quần vợt và bóng quần vợt trên sân quần vợt
#
# Explanation 1: the boy has a racket and tennis ball
# Argmax: cậu bé có một cây vợt và quả bóng tennis
# Sampling: cậu bé có vợt và bóng quần vợt
#   vinai: Thằng bé có vợt và bóng tennis.
#   gemini: cậu bé có vợt và bóng quần vợt
#   ggtrans: cậu bé có một cây vợt và quả bóng tennis
#   gpt: cậu bé có một chiếc vợt và một quả bóng quần vợt
#
# ====================================================================================================
# ID: 509509001
# Question: Is the man in a suit?
# Answers: no
# Explanation 0: he has a loose black sweatshirt on
# Argmax: anh ấy mặc một chiếc áo nỉ màu đen rộng thùng thình
# Sampling: anh ấy mặc một chiếc áo nỉ màu đen rộng thùng thình
#   vinai: Anh ta mặc áo len màu đen rộng.
#   gemini: anh ấy mặc áo thun đen rộng
#   ggtrans: anh ấy mặc một chiếc áo nỉ màu đen rộng thùng thình
#   gpt: anh ấy đang mặc một chiếc áo nỉ đen rộng rãi
#
# ====================================================================================================
# ID: 77805002
# Question: What is the bird doing?
# Answers: eating
# Explanation 0: the man held food out in his hand
# Argmax: người đàn ông đưa thức ăn ra trên tay
# Sampling: người đàn ông đưa thức ăn ra trên tay
#   vinai: Người đàn ông đưa thức ăn ra trong tay.
#   gemini: người đàn ông đã đưa thức ăn ra tay
#   ggtrans: người đàn ông đưa thức ăn ra trên tay
#   gpt: người đàn ông cầm thức ăn trong tay
#
# ====================================================================================================
# ID: 172092002
# Question: Is the lady amused?
# Answers: yes
# Explanation 0: she has a smile on her face
# Argmax: Cô ấy có nụ cười trên khuôn mặt.
# Sampling: cô ấy có một nụ cười trên khuôn mặt
#   vinai: Cô ấy có nụ cười trên khuôn mặt.
#   gemini: cô ấy đang cười
#   ggtrans: cô ấy có một nụ cười trên khuôn mặt
#   gpt: Cô ấy đang mỉm cười trên khuôn mặt.
#
# ====================================================================================================
# ID: 232181022
# Question: Does someone really want people to stop here?
# Answers: yes
# Explanation 0: there are four stop signs urging people to stop
# Argmax: có bốn biển báo dừng yêu cầu mọi người dừng lại
# Sampling: có bốn biển báo dừng yêu cầu mọi người dừng lại
#   vinai: Có bốn biển báo dừng kêu gọi mọi người dừng lại.
#   gemini: có bốn biển báo dừng yêu cầu mọi người dừng lại
#   ggtrans: có bốn biển báo dừng kêu gọi mọi người dừng lại
#   gpt: Có bốn biển báo dừng yêu cầu mọi người dừng lại.
#
# ====================================================================================================

# %%
# add img_id column to argmax and sampling data
import os
import json
import pandas as pd
datasets_dir = "../../../datasets"
vqax_dir = os.path.join(datasets_dir, "VQA-X")
sampling_dir = os.path.join(vqax_dir, "final_data/sampling")
datasets = ["train", "val", "test"]

for dataset in datasets:
    print(f"Processing {dataset} dataset...")
    sampling_file = os.path.join(sampling_dir, f"{dataset}_sampling.csv")
    orginal_file = os.path.join(vqax_dir, f"vqaX_{dataset}.json")
    sampling_data = pd.read_csv(sampling_file)
    with open(orginal_file) as f:
        original_data = json.load(f)
    sampling_data["img_id"] = sampling_data["question_id"].apply(lambda x: original_data[str(x)]["image_name"].split(".")[0])
    # sampling_data.to_csv(os.path.join(vqax_dir, f"{dataset}_sampling.csv"), index=False, encoding="utf-8", columns=["question_id", "img_id", "question", "answer", "explanation"])
    sampling_data.to_csv(sampling_file, index=False, encoding="utf-8", columns=["question_id", "img_id", "question", "answer", "explanation"])

    print(f"Saved {sampling_file}")
# Out:
# Processing train dataset...
# Saved ../../../datasets/VQA-X/final_data/sampling/train_sampling.csv
# Processing val dataset...
# Saved ../../../datasets/VQA-X/final_data/sampling/val_sampling.csv
# Processing test dataset...
# Saved ../../../datasets/VQA-X/final_data/sampling/test_sampling.csv

# %% [markdown]
# ## Check the score of the translations

# %%
import os
import json

# Đường dẫn tới thư mục datasets và evaluation
datasets_dir = '../../../datasets/VQA-X'
evaluation_dir = os.path.join(datasets_dir, 'evaluation')
llm_models = ['llama', 'qwen', 'phi','gemma','gpt']
evaluation_files = ['val', 'test', 'train']

# Hàm kiểm tra các trường score
def check_scores_length(data):
    errors = []
    for entry in data:
        if len(entry['question_scores']) != len(entry['question']):
            errors.append(f"Mismatch in question_scores: {entry['id_image']}")
        if len(entry['answer_scores']) != len(entry['answer']):
            errors.append(f"Mismatch in answer_scores: {entry['id_image']}")
        for i, expl_scores in enumerate(entry['explanation_scores']):
            try:
                if len(expl_scores) != len(entry['explanation'][i]):
                    errors.append(f"Mismatch in explanation_scores[{i}]: {entry['id_image']}")
            except:
                errors.append(f"Error in explanation_scores[{i}]: {entry['id_image']}")

    return errors

# Kiểm tra các file JSON của từng LLM
for model in llm_models:
    for eval_file in evaluation_files:
        file_path = os.path.join(evaluation_dir, f"{eval_file}_{model}_evaluation.json")
        if os.path.exists(file_path):
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)            
                errors = check_scores_length(data)
                if errors:
                    print(f"Errors in {file_path}:")
                    for error in errors:
                        print(f"  - {error}")
                else:
                    print(f"No errors found in {eval_file}_{model}_evaluation.json")
        else:
            print(f"File {file_path} does not exist.")
# Out:
# No errors found in val_llama_evaluation.json
# No errors found in test_llama_evaluation.json
# No errors found in train_llama_evaluation.json
# No errors found in val_qwen_evaluation.json
# No errors found in test_qwen_evaluation.json
# No errors found in train_qwen_evaluation.json
# No errors found in val_phi_evaluation.json
# No errors found in test_phi_evaluation.json
# No errors found in train_phi_evaluation.json
# No errors found in val_gemma_evaluation.json
# No errors found in test_gemma_evaluation.json
# No errors found in train_gemma_evaluation.json
# No errors found in val_gpt_evaluation.json
# No errors found in test_gpt_evaluation.json
# No errors found in train_gpt_evaluation.json

# %% [markdown]
# ## Merge the scores

# %%
import json
import os

datasets_dir = '../../../datasets/VQA-X'
evaluation_dir = os.path.join(datasets_dir, 'evaluation')
llm_models = ['llama', 'qwen', 'phi', 'gemma', 'gpt']
evaluation_files = ['train', 'val', 'test']

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return json.load(file)

def merge_evaluation_data(**json_files):
    merged_data = {}
    
    for model_name, file_path in json_files.items():
        data = load_json(file_path)
        
        for entry in data:
            question_id = entry["id_image"] # need to change to question_id
            if question_id not in merged_data:
                merged_data[question_id] = {
                    "question_id": question_id,
                    "question": entry["question"],
                    "question_scores": {},
                    "answer": entry["answer"],
                    "answer_scores": {},
                    "explanation": entry["explanation"],
                    "explanation_scores": {model_name: entry["explanation_scores"]}
                }
            
            # Add scores with the model name as the key
            merged_data[question_id]["question_scores"][model_name] = entry["question_scores"]
            merged_data[question_id]["answer_scores"][model_name] = entry["answer_scores"]
        
            merged_data[question_id]["explanation_scores"][model_name] = entry["explanation_scores"]

    return list(merged_data.values())

# Process each dataset (train, val, test)
for evaluation_file in evaluation_files:
    # Define paths to the JSON files for each model and the current evaluation file
    json_files = {
        model: os.path.join(evaluation_dir, f"{evaluation_file}_{model}_evaluation.json")
        for model in llm_models
    }
    
    # Merge the data for the current evaluation file
    merged_data = merge_evaluation_data(**json_files)
    
    # Save the merged data
    output_path = os.path.join(evaluation_dir, f'vqaX_{evaluation_file}_evaluation.json')
    with open(output_path, 'w', encoding='utf-8') as outfile:
        json.dump(merged_data, outfile, indent=2, ensure_ascii=False)
    
    print(f"Merged data for {evaluation_file} saved to {output_path}")
# Out:
# Merged data for train saved to ../../../datasets/VQA-X/evaluation/vqaX_train_evaluation.json
# Merged data for val saved to ../../../datasets/VQA-X/evaluation/vqaX_val_evaluation.json
# Merged data for test saved to ../../../datasets/VQA-X/evaluation/vqaX_test_evaluation.json

# %% [markdown]
# ## Test gpt

# %%
import openai
import json
from dotenv import load_dotenv
import os
load_dotenv()
# Đặt API key của bạn
openai.api_key = os.getenv("OPENAI_API_KEY")
prompt = """
You will be given an English question, answer, and explanations for context. Then, you will evaluate Vietnamese translations of the question, answer, and explanation(s). Evaluate each translation based on accuracy, fluency, and cultural appropriateness, considering the full context provided. Assign a score between 0 and 100 for each translation.

**Return the scores in the following JSON format and no additional text or explanations:**

{{
    "question_scores": [score_for_translation_1, score_for_translation_2, ...],
    "answer_scores": [score_for_translation_1, score_for_translation_2, ...],
    "explanation_scores": [
        [score for translations of explanation 1],
        [score for translations of explanation 2], (if multiple explanations are provided)
        ...
    ] (length of this list should match the number of explanations provided)
}}

Now, please evaluate the following:
"""
content_user = """
English Question: How many legs does a cat have?
Translation 1: Mèo có bao nhiêu chân?
Translation 2: Mèo có mấy chân?
Translation 3: Mèo có mấy cái chân?

English Answer: A cat has four legs.
Translation 1: Mèo có bốn chân.
Translation 2: Mèo có 4 chân.
Translation 3: Mèo có bốn cái chân.

Explanation 1: Cats are quadrupedal animals.
Translation 1: Mèo là động vật có bốn chân.
Translation 2: Mèo là loài động vật có bốn chân.
Translation 3: Mèo là loài động vật có bốn cái chân.
"""


messages = [
    {"role": "system", "content": prompt},
    {"role": "user", "content": content_user}
]

# Gọi API
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    max_tokens=100,
    temperature=0.1,
    response_format={"type": "json_object"}
)

# %%
print(response.choices[0].message.content)
json_object = json.loads(response.choices[0].message.content)
json_object['explain_score']
# Out:
# {
#     "question_score": [90, 95, 85],
#     "answer_score": [95, 95, 85],
#     "explain_score": [
#         [90, 95, 85]
#     ]
# }
# [[90, 95, 85]]

# %% [markdown]
# ## Evaluate predictions

# %%
import json
import os
import pandas as pd
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider
from fairseq.data.encoders.gpt2_bpe import GPT2BPE, GPT2BPEConfig

# Tạo đối tượng BPE với đường dẫn đến các file vocab và encoder.json
bpe_cfg = {
    'gpt2_encoder_json': '/home/VLAI/binhdt/OFA-X/OFA/utils/BPE/encoder.json',
    'gpt2_vocab_bpe': '/home/VLAI/binhdt/OFA-X/OFA/utils/BPE/vocab.bpe'
}
bpe = GPT2BPE(GPT2BPEConfig(bpe_cfg))

# Hàm giải mã BPE
def decode_bpe(encoded_tokens, bpe):
    decoded_text = bpe.decode(' '.join(map(str, encoded_tokens)))
    return decoded_text

def encode_bpe(text, bpe):
    encoded_tokens = bpe.encode(text)
    return encoded_tokens

# Đọc file JSON
test_predict_file = '/home/VLAI/binhdt/OFA-X/results/bz_32_0.4161/test_predict.json'
with open(test_predict_file, 'r', encoding='utf-8') as f:
    test_predict = json.load(f)

predict_df = pd.DataFrame(test_predict)

# Áp dụng giải mã cho cột target_explanation và explanation (chỉ nếu là danh sách BPE)
predict_df['target_explanation'] = predict_df['target_explanation'].apply(lambda x: decode_bpe(x, bpe))
# predict_df['explanation'] = predict_df['explanation'].apply(lambda x: encode_bpe(x, bpe))
# # chuyển list sang string
# predict_df['target_explanation'] = predict_df['target_explanation'].apply(lambda x: ' '.join(map(str, x)))
predict_df.head()
# Out:
#           id     answer                                        explanation  \
# 0  262284001  phòng tắm                   vì có vòi hoa sen và vòi hoa sen
# 1  262284001  phòng tắm                   vì có vòi hoa sen và vòi hoa sen
# 2  262284001  phòng tắm                   vì có vòi hoa sen và vòi hoa sen
# 3  393372017      không  vì cô ấy đang mỉm cười và cô ấy đang đứng trên...
# 4  393372017      không  vì cô ấy đang mỉm cười và cô ấy đang đứng trên...
#
#                                   target_explanation
# 0   desinter shaped�cert desinter Hamiltonion fre...
# 1   desinter shaped�cert desinter Hamiltonrough f...
# 2   desinter shaped�cert desinter Hamiltonrough f...
# 3   agreeunny visual answ desinter Hamilton butar...
# 4   agreeunny visual answ desinter Hamiltonroughj...

# %%
# Chuẩn bị dữ liệu tham chiếu (references) và dự đoán (hypotheses)
gts = {idx: [ref] for idx, ref in enumerate(predict_df['target_explanation'])}
res = {idx: [hyp] for idx, hyp in enumerate(predict_df['explanation'])}

# Khởi tạo các đối tượng tính điểm
bleu_scorer = Bleu(4)  # Bleu-1 đến Bleu-4
meteor_scorer = Meteor()
rouge_scorer = Rouge()
cider_scorer = Cider()

# Tính điểm Bleu
bleu_score, bleu_scores = bleu_scorer.compute_score(gts, res)
print(f"Bleu Scores: {bleu_score}")

# Tính điểm METEOR
meteor_score, meteor_scores = meteor_scorer.compute_score(gts, res)
print(f"METEOR Score: {meteor_score}")

# Tính điểm ROUGE_L
rouge_score, rouge_scores = rouge_scorer.compute_score(gts, res)
print(f"ROUGE_L Score: {rouge_score}")

# Tính điểm CIDEr
cider_score, cider_scores = cider_scorer.compute_score(gts, res)
print(f"CIDEr Score: {cider_score}")
# Out:
# {'testlen': 56313, 'reflen': 121129, 'guess': [56313, 50412, 44511, 38610], 'correct': [0, 0, 0, 0]}
# ratio: 0.46490105589907893
# Bleu Scores: [5.617206829634975e-21, 5.936873340529306e-21, 6.303654937497847e-21, 6.730566868823769e-21]
# METEOR Score: 0.0002329689443605222
# ROUGE_L Score: 5.049042473869292e-05
# CIDEr Score: 0.0

# %%
import pandas as pd
test_file = '/home/VLAI/binhdt/OFA-X/data/vqax/vqaX_test_translated.tsv'
test_df = pd.read_csv(test_file, sep='\t', header=None, names=['question_id', 'img_id', 'question', 'conf|!+answer', 'explanation', 'empty', 'base64_encoded_image'])

# %%
import json
import os
import pandas as pd
test_predict_file = '/home/VLAI/binhdt/OFA-X/results/bz_32_0.4161/test_predict.json'
with open(test_predict_file, 'r', encoding='utf-8') as f:
    test_predict = json.load(f)
    
predict_df = pd.DataFrame(test_predict)
predict_df.drop(columns=['target_explanation'], inplace=True)
grouped_target = test_df[['question_id', 'explanation']].groupby('question_id')['explanation'].apply(list).reset_index()

# Chuyển 'question_id' thành 'id' để có thể merge với 'predict_df'
grouped_target = grouped_target.rename(columns={'question_id': 'id'})

# Convert 'id' columns to the same data type
grouped_target['id'] = grouped_target['id'].astype(str)
predict_df['id'] = predict_df['id'].astype(str)

# Merge các câu giải thích từ test.tsv vào prediction df
merged_df = pd.merge(predict_df, grouped_target, how='left', on='id')

# "Explode" cột 'target_explanation' để mỗi hàng chỉ chứa một giải thích
merged_df = merged_df.explode('explanation_y')

# Đặt lại tên cột để cột 'explanation_y' trở thành 'target_explanation'
merged_df = merged_df.rename(columns={'explanation_y': 'target_explanation'})
merged_df = merged_df.rename(columns={'explanation_x': 'explanation'})
merged_df['explanation'] = merged_df['explanation'].apply(lambda x: x.lstrip("vì "))
# target_answer
merged_df['target_answer'] = test_df['conf|!+answer'].apply(lambda x: x.split('|!+')[1])
# drop duplicate
merged_df = merged_df.drop_duplicates(subset=['id', 'answer', 'explanation', 'target_explanation'])
merged_df.head()
# Out:
#           id     answer                                      explanation  \
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 3  393372017      không  cô ấy đang mỉm cười và cô ấy đang đứng trên đầu
# 3  393372017      không  cô ấy đang mỉm cười và cô ấy đang đứng trên đầu
#
#                                   target_explanation target_answer
# 0                   nó có vòi hoa sen treo bên trong       vòi sen
# 0                                     có vòi hoa sen       vòi sen
# 0                             có vòi nước và bồn tắm       vòi sen
# 3                mắt cô ấy mở và hướng về phía trước          Đúng
# 3  cô ấy đang hướng về phía máy ảnh và tạo dáng t...          Đúng

# %%
import regex as re
def clean(st):
    # remove everything in between parentheses
    return re.sub(r" \([^)]*\)", "", st)

# clean merge df
merged_df['answer'] = merged_df['answer'].apply(lambda x: clean(x))
merged_df['explanation'] = merged_df['explanation'].apply(lambda x: clean(x))
merged_df['target_explanation'] = merged_df['target_explanation'].apply(lambda x: clean(x))
merged_df['target_answer'] = merged_df['target_answer'].apply(lambda x: clean(x))
merged_df.head()
# Out:
#           id     answer                                      explanation  \
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 0  262284001  phòng tắm                    có vòi hoa sen và vòi hoa sen
# 3  393372017      không  cô ấy đang mỉm cười và cô ấy đang đứng trên đầu
# 3  393372017      không  cô ấy đang mỉm cười và cô ấy đang đứng trên đầu
#
#                                   target_explanation target_answer
# 0                   nó có vòi hoa sen treo bên trong       vòi sen
# 0                                     có vòi hoa sen       vòi sen
# 0                             có vòi nước và bồn tắm       vòi sen
# 3                mắt cô ấy mở và hướng về phía trước          Đúng
# 3  cô ấy đang hướng về phía máy ảnh và tạo dáng t...          Đúng

# %%
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.meteor.meteor import Meteor
from pycocoevalcap.rouge.rouge import Rouge
from pycocoevalcap.cider.cider import Cider

# Chuẩn bị dữ liệu tham chiếu (references) và dự đoán (hypotheses)
gts = {idx: [ref] for idx, ref in enumerate(merged_df['target_explanation'].tolist())}
res = {idx: [hyp] for idx, hyp in enumerate(merged_df['explanation'].tolist())}

# Khởi tạo các đối tượng tính điểm
bleu_scorer = Bleu(4)  # Bleu-1 đến Bleu-4
meteor_scorer = Meteor()
rouge_scorer = Rouge()
cider_scorer = Cider()

# Tính điểm Bleu
bleu_score, bleu_scores = bleu_scorer.compute_score(gts, res)
for i, score in enumerate(bleu_score):
    print(f"Bleu-{i+1} Score: {score:.4f}")

# Tính điểm METEOR
meteor_score, meteor_scores = meteor_scorer.compute_score(gts, res)
print(f"METEOR Score: {meteor_score:.4f}")

# Tính điểm ROUGE_L
rouge_score, rouge_scores = rouge_scorer.compute_score(gts, res)
print(f"ROUGE_L Score: {rouge_score:.4f}")

# Tính điểm CIDEr
cider_score, cider_scores = cider_scorer.compute_score(gts, res)
print(f"CIDEr Score: {cider_score:.4f}")

# Tính accuracy
accuracy = (merged_df['target_answer'] == merged_df['answer']).mean()
print(f"Accuracy: {accuracy:.4f}")
# Out:
# {'testlen': 50178, 'reflen': 60729, 'guess': [50178, 44305, 38432, 32559], 'correct': [17095, 6793, 2761, 1144]}
# ratio: 0.8262609297040817
# Bleu-1 Score: 0.2761
# Bleu-2 Score: 0.1852
# Bleu-3 Score: 0.1259
# Bleu-4 Score: 0.0868
# METEOR Score: 0.1690
# ROUGE_L Score: 0.2831
# CIDEr Score: 0.8055
# Accuracy: 0.4723

# %%
from nlgeval import NLGEval
import numpy as np

def get_nlg_scores_aggregated(references, hypotheses):
    """
    Tính toán điểm số NLG cho toàn bộ tập dữ liệu bằng cách tính tổng của tất cả các cặp câu trước, 
    sau đó chia cho số lượng cặp.

    Args:
    references (list): Danh sách các câu tham chiếu
    hypotheses (list): Danh sách các câu giả thuyết

    Returns:
    dict: Từ điển chứa các điểm số trung bình cho toàn bộ tập dữ liệu
    """
    nlgeval = NLGEval(no_skipthoughts=True, no_glove=True, metrics_to_omit=["SPICE"])
    
    # Tính toán điểm số cho từng cặp (tham chiếu, giả thuyết)
    all_scores = []
    for refs, hyp in zip(references, hypotheses):
        if isinstance(refs, str):
            refs = [refs]  # Đảm bảo refs luôn là một danh sách
        scores = nlgeval.compute_individual_metrics(refs, hyp)
        all_scores.append(scores)

    # Tính trung bình các điểm số
    avg_scores = {
        metric: np.mean([score[metric] for score in all_scores])
        for metric in all_scores[0]
    }

    # Chỉ giữ lại các metric phù hợp với VQA-X
    relevant_metrics = [
        "Bleu_1",
        "Bleu_2",
        "Bleu_3",
        "Bleu_4",
        "METEOR",
        "ROUGE_L",
        "CIDEr",
    ]

    return {k: v for k, v in avg_scores.items() if k in relevant_metrics}

# Chuẩn bị dữ liệu mẫu cho câu tham chiếu và dự đoán
target_explanations = merged_df['target_explanation'].tolist()
predicted_explanations = merged_df['explanation'].tolist()

# Tính toán các điểm số
scores = get_nlg_scores_aggregated(target_explanations, predicted_explanations)

# In ra các điểm số
print("Các điểm số trung bình cho toàn bộ tập dữ liệu:")
for metric, score in scores.items():
    print(f"{metric}: {score:.4f}")
# Out:
# Các điểm số trung bình cho toàn bộ tập dữ liệu:
# Bleu_1: 0.2489
# Bleu_2: 0.1472
# Bleu_3: 0.0769
# Bleu_4: 0.0397
# METEOR: 0.1764
# ROUGE_L: 0.2831
# CIDEr: 0.0000

# %%
def compute_metrics_from_lists(hypotheses, references_list, no_overlap=False, no_skipthoughts=False, no_glove=False):
    """
    Hàm tính toán điểm số NLG trực tiếp từ danh sách các câu tham chiếu và giả thuyết.
    
    Args:
    hypotheses (list): Danh sách các câu giả thuyết
    references_list (list of list): Danh sách các danh sách câu tham chiếu
    """
    # Chuyển danh sách câu tham chiếu và giả thuyết thành dictionary
    refs = {idx: [line.strip() for line in strippedlines] for idx, strippedlines in enumerate(references_list)}
    hyps = {idx: [lines.strip()] for (idx, lines) in enumerate(hypotheses)}
    
    # print(hyps)
    # print(refs)
    # print(len(refs), len(hyps))

    assert len(refs) == len(hyps), "Số lượng câu tham chiếu và giả thuyết không khớp!"

    ret_scores = {}
    if not no_overlap:
        scorers = [
            (Bleu(4), ["Bleu_1", "Bleu_2", "Bleu_3", "Bleu_4"]),
            (Meteor(), "METEOR"),
            (Rouge(), "ROUGE_L"),
            (Cider(), "CIDEr"),
        ]
        for scorer, method in scorers:
            score, scores = scorer.compute_score(refs, hyps)
            if isinstance(method, list):
                for sc, scs, m in zip(score, scores, method):
                    ret_scores[m] = sc
            else: 
                ret_scores[method] = score

        del scorers


    return ret_scores

# Chuẩn bị danh sách câu tham chiếu và giả thuyết
target_explanations = merged_df['target_explanation'].tolist()
predicted_explanations = merged_df['explanation'].tolist()

# Đảm bảo rằng target_explanations là danh sách của danh sách, mỗi câu giả thuyết có thể có nhiều tham chiếu
target_explanations_list = [[ref] for ref in target_explanations]

# Tính toán các điểm số
scores = compute_metrics_from_lists(predicted_explanations, target_explanations_list)

# In ra các điểm số
print("Các điểm số trung bình cho toàn bộ tập dữ liệu:")
for metric, score in scores.items():
    print(f"{metric}: {score:.4f}")
# Out:
# {'testlen': 50178, 'reflen': 60729, 'guess': [50178, 44305, 38432, 32559], 'correct': [17095, 6793, 2761, 1144]}
# ratio: 0.8262609297040817
# Các điểm số trung bình cho toàn bộ tập dữ liệu:
# Bleu_1: 0.2761
# Bleu_2: 0.1852
# Bleu_3: 0.1259
# Bleu_4: 0.0868
# METEOR: 0.1690
# ROUGE_L: 0.2831
# CIDEr: 0.8055
